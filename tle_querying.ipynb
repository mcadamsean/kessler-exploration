# %%
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from datetime import datetime, timedelta
from sgp4.api import Satrec, WGS72, jday
import nbformat
import time      
import random 
import sqlite3

# %%
from dateutil.relativedelta import relativedelta

# %%
# Set the information needed to log into Space-Track and acess the query page
USERNAME = "EMAIL"
PASSWORD = "PASSWORD"

LOGIN_URL = "https://www.space-track.org/ajaxauth/login"

# %%
EARTH_RADIUS = 6371
SNAPSHOT_TIME = datetime(2025, 1, 20, 0, 0, 0)
DURATION_MINUTES = 1440  # 24 hours
STEP_SECONDS = 60
ORBIT_SUBSET = 5

# %%
# -------------------------------------------------------------------
# 1) Log into Space-Track and retrieve TLEs
# -------------------------------------------------------------------

def fetch_tle_text(username, password, query_url):
    """
    Logs into Space-Track using the provided credentials
    and performs a GET request on the specified query_url.
    Returns raw TLE text in 3-line format if successful.
    """
    with requests.Session() as session:
        # Log in
        login_data = {"identity": username, "password": password}
        login_resp = session.post(LOGIN_URL, data=login_data)
        login_resp.raise_for_status()
        
        # Perform the query
        resp = session.get(query_url)
        resp.raise_for_status()
        
        return resp.text

# -------------------------------------------------------------------
# 2) Parse raw TLE text into a DataFrame with Name, Line1, Line2
# -------------------------------------------------------------------

def parse_tle_to_dataframe(tle_text):
    lines = [line.strip() for line in tle_text.strip().splitlines() if line.strip()]
    satellites = []

    if len(lines) % 3 != 0:
        print("Warning: The number of lines is not a multiple of 3. Some TLE entries may be incomplete.")

    for i in range(0, len(lines) - 2, 3):
        name_line = lines[i]
        line1 = lines[i + 1]
        line2 = lines[i + 2]

        if not name_line.startswith("0"):
            print(f"Unexpected format in name line: '{name_line}'. Skipping.")
            continue
        if not line1.startswith("1"):
            print(f"Unexpected format in Line 1: '{line1}'. Skipping.")
            continue
        if not line2.startswith("2"):
            print(f"Unexpected format in Line 2: '{line2}'. Skipping.")
            continue

        name = name_line[1:].strip()  # Remove leading "0"
        satellites.append({"Name": name, "Line1": line1, "Line2": line2})

    return pd.DataFrame(satellites, columns=["Name", "Line1", "Line2"])

# -------------------------------------------------------------------
# 3) Extract extra TLE fields
# -------------------------------------------------------------------

def extract_launch_year(line1):
    """
    Extract 4-digit launch year from TLE's Line1 (international designator).
    """
    try:
        parts = line1.split()
        int_designator = parts[2]
        yy = int(int_designator[:2])
        # TLE convention: if year >= 57 => 19xx, else 20xx
        if yy >= 57:
            return 1900 + yy
        else:
            return 2000 + yy
    except (IndexError, ValueError) as e:
        print(f"Error extracting launch year from Line1: '{line1}'. Error: {e}")
        return None

def extract_tle_epoch(line1):
    """
    Extract datetime from TLE epoch encoded in Line1.
    """
    try:
        match = re.search(r'(\d{2})(\d{3}\.\d+)', line1)
        if not match:
            return None
        
        year = int(match.group(1))
        day_of_year = float(match.group(2))

        if year >= 57:
            year += 1900
        else:
            year += 2000

        base_date = datetime(year, 1, 1)
        epoch_date = base_date + timedelta(
            days=int(day_of_year) - 1,
            seconds=(day_of_year % 1) * 86400
        )
        return epoch_date
    except Exception as e:
        print(f"Error extracting epoch: {e}")
        return None

# -------------------------------------------------------------------
# 4) Propagate orbits via SGP4 (x, y, z in km)
# -------------------------------------------------------------------

def jday(year, mon, day, hr, minute, sec):
    """
    Helper from sgp4.
    Given year, month, day, hour, minute, second -> Julian day, fraction
    """
    # Based on original sgp4.py jday() approach
    # This is typically available in sgp4.api, but we replicate for clarity
    jd = (367.0 * year
          - int((7 * (year + int((mon + 9) / 12.0))) * 0.25)
          + int(275 * mon / 9.0)
          + day + 1721013.5)
    frac = (hr + minute/60.0 + sec/3600.0) / 24.0
    return jd, frac

def get_satellite_position(line1, line2, when):
    """
    Returns the satellite's ECI position [km] (x,y,z) at the given datetime 'when'.
    """
    try:
        sat = Satrec.twoline2rv(line1, line2, WGS72)
        jd, fr = jday(
            when.year, when.month, when.day,
            when.hour, when.minute, when.second + when.microsecond * 1e-6
        )
        error_code, r, v = sat.sgp4(jd, fr)
        if error_code != 0:
            print(f"SGP4 Error {error_code} for Satellite: {sat.satnum}")
            return None
        return r  # [x, y, z] in km
    except Exception as e:
        print(f"Exception during propagation: {e}")
        return None

def get_satellite_tracks(line1, line2, start_datetime, duration_minutes=90, step_seconds=30):
    """
    Propagate satellite positions over a duration, returning lists of x, y, z in km.
    """
    sat = Satrec.twoline2rv(line1, line2, WGS72)
    positions_x, positions_y, positions_z = [], [], []

    total_steps = int((duration_minutes * 60) / step_seconds)
    for step in range(total_steps + 1):
        current_time = start_datetime + timedelta(seconds=step * step_seconds)
        jd, fr = jday(
            current_time.year, current_time.month, current_time.day,
            current_time.hour, current_time.minute, current_time.second + current_time.microsecond * 1e-6
        )
        e, r, v = sat.sgp4(jd, fr)
        if e == 0:
            positions_x.append(r[0])
            positions_y.append(r[1])
            positions_z.append(r[2])
        else:
            positions_x.append(np.nan)
            positions_y.append(np.nan)
            positions_z.append(np.nan)

    return positions_x, positions_y, positions_z

# -------------------------------------------------------------------
# 5) Parameterized function to pull TLE data for any query URL
# -------------------------------------------------------------------

def pull_tle_data_for_query(username, password, query_url):
    """
    Fetch TLE data from a custom query URL, parse, and return
    a DataFrame plus position arrays, tracks, etc.

    Returns:
      filtered_df (DataFrame): columns Name, Line1, Line2, Launch Year, Epoch
      xs, ys, zs (list): positions at single snapshot time
      launch_years (list): repeated from df
      orbits_data (list of dicts): track data for the first ORBIT_SUBSET satellites
    """
    # 1) Fetch
    tle_text = fetch_tle_text(username, password, query_url=query_url)

    # 2) Parse
    df = parse_tle_to_dataframe(tle_text)

    # 3) Enrich with Launch Year & Epoch
    df['Launch Year'] = df['Line1'].apply(extract_launch_year)
    df['Epoch'] = df['Line1'].apply(extract_tle_epoch)

    # For historical data, we won't filter by recency
    filtered_df = df

    # 5) Get x, y, z for each satellite at a single snapshot time
    xs, ys, zs = [], [], []
    launch_years = []
    for _, row in filtered_df.iterrows():
        pos = get_satellite_position(row['Line1'], row['Line2'], SNAPSHOT_TIME)
        if pos is not None:
            xs.append(pos[0])
            ys.append(pos[1])
            zs.append(pos[2])
            launch_years.append(row['Launch Year'])
        else:
            xs.append(np.nan)
            ys.append(np.nan)
            zs.append(np.nan)
            launch_years.append(np.nan)

    # 6) Generate orbital tracks for a subset (optional)
    # This is separate "time series" data
    subset_df = filtered_df.head(ORBIT_SUBSET)
    orbits_data = []
    for idx, row in subset_df.iterrows():
        track_x, track_y, track_z = get_satellite_tracks(
            row['Line1'], row['Line2'],
            SNAPSHOT_TIME,
            duration_minutes=DURATION_MINUTES,
            step_seconds=STEP_SECONDS
        )
        orbits_data.append({
            'Index': idx,
            'Name': row['Name'],
            'Launch Year': row['Launch Year'],
            'X_track': track_x,
            'Y_track': track_y,
            'Z_track': track_z
        })

    return filtered_df, xs, ys, zs, launch_years, orbits_data

# -------------------------------------------------------------------
# 6) Utility function to build monthly Space-Track URLs
# -------------------------------------------------------------------

def build_monthly_query_url(start_date, end_date):
    """
    Builds a Space-Track query URL to get all TLEs (class=tle_archive)
    with EPOCH between start_date and end_date.
    """
    start_str = start_date.strftime("%Y-%m-%d")
    end_str   = end_date.strftime("%Y-%m-%d")

    base_url = "https://www.space-track.org/basicspacedata/query/class/gp/"
    # Using range syntax: EPOCH/START--END
    query_url = (
        f"{base_url}"
        f"EPOCH/{start_str}--{end_str}/"
        "orderby/EPOCH%20asc/format/3le"
    )
    return query_url

# -------------------------------------------------------------------
# 7) Main loop: fetch monthly TLE data, THROTTLED
# -------------------------------------------------------------------

def main():
    """
    Runs from 2000-01-01 up to now, one month at a time.
    Returns a single DataFrame with all satellite records
    (including single-snapshot positions X, Y, Z).
    """
    current_date = datetime(2000, 1, 1)
    last_date = datetime.now()

    # We'll accumulate each month's data in a list
    all_data_months = []

    while current_date < last_date:
        month_start = current_date.replace(day=1, hour=0, minute=0, second=0, microsecond=0)
        next_month_start = month_start + relativedelta(months=1)

        query_url = build_monthly_query_url(month_start, next_month_start)

        # ----- Perform the query for this month -----
        df, xs, ys, zs, launch_years, orbits_data = pull_tle_data_for_query(
            USERNAME,
            PASSWORD,
            query_url
        )
        print(f"Month: {month_start.strftime('%Y-%m')} -> TLE DF size: {len(df)}")

        # Combine monthly TLE df with the snapshot position columns
        # so we keep them in one DataFrame
        month_df = df.copy()  # start with Name, Line1, Line2, Launch Year, Epoch
        month_df['X'] = xs
        month_df['Y'] = ys
        month_df['Z'] = zs
        # We also record which snapshot time we used for these positions
        month_df['Snapshot_Time'] = SNAPSHOT_TIME

        # Now store this monthly DataFrame in a list
        all_data_months.append(month_df)

        # ------------- IMPORTANT THROTTLING -------------
        time.sleep(60 + random.random())  # to keep well below 30 requests/min

        current_date = next_month_start

    # After the loop, combine all months into a single DataFrame
    if all_data_months:
        final_df = pd.concat(all_data_months, ignore_index=True)
    else:
        # Edge case if no data was fetched
        final_df = pd.DataFrame(columns=["Name","Line1","Line2","Launch Year",
                                         "Epoch","X","Y","Z","Snapshot_Time"])

    # Return the final DataFrame so the caller can save it or process it further
    return final_df

# %%
big_df = main()

print("Total rows in final DataFrame:", len(big_df))
# For demonstration, let's save it as CSV:
big_df.to_csv("all_tle_snapshots.csv", index=False)
print("Saved all TLE snapshots to CSV: all_tle_snapshots.csv")

# If you also want an SQL approach:
print("Creating SQLite table from the DataFrame...")
conn = sqlite3.connect("tle_snapshots.db")
big_df.to_sql("satellite_positions", conn, if_exists="replace", index=False)
conn.close()
print("Wrote 'satellite_positions' table to tle_snapshots.db")
# Out:
# SGP4 Error 1 for Satellite: 24620
# SGP4 Error 1 for Satellite: 23575
# SGP4 Error 1 for Satellite: 7847
# SGP4 Error 1 for Satellite: 22564
# SGP4 Error 1 for Satellite: 5999
# SGP4 Error 1 for Satellite: 25663
# SGP4 Error 1 for Satellite: 25796
# SGP4 Error 1 for Satellite: 1962
# SGP4 Error 1 for Satellite: 7842
# SGP4 Error 1 for Satellite: 24240
# SGP4 Error 1 for Satellite: 24111
# SGP4 Error 1 for Satellite: 26044
# SGP4 Error 1 for Satellite: 7969
# SGP4 Error 1 for Satellite: 24368
# SGP4 Error 1 for Satellite: 25950
# SGP4 Error 1 for Satellite: 22346
# SGP4 Error 1 for Satellite: 24024
# SGP4 Error 1 for Satellite: 26055
# SGP4 Error 1 for Satellite: 20759
# SGP4 Error 1 for Satellite: 13964
# SGP4 Error 1 for Satellite: 16885
# SGP4 Error 1 for Satellite: 25220
# Month: 2000-01 -> TLE DF size: 23
# SGP4 Error 1 for Satellite: 24614
# SGP4 Error 1 for Satellite: 25176
# SGP4 Error 1 for Satellite: 26068
# SGP4 Error 1 for Satellite: 25858
# SGP4 Error 1 for Satellite: 24331
# SGP4 Error 1 for Satellite: 22890
# SGP4 Error 1 for Satellite: 22702
# SGP4 Error 1 for Satellite: 26043
# SGP4 Error 1 for Satellite: 26087
# SGP4 Error 1 for Satellite: 3343
# SGP4 Error 1 for Satellite: 22822
# SGP4 Error 1 for Satellite: 24054
# SGP4 Error 1 for Satellite: 9854
# SGP4 Error 1 for Satellite: 25911
# SGP4 Error 1 for Satellite: 24528
# SGP4 Error 1 for Satellite: 25769
# SGP4 Error 1 for Satellite: 25752
# SGP4 Error 1 for Satellite: 26088
# SGP4 Error 1 for Satellite: 20680
# Month: 2000-02 -> TLE DF size: 22
# SGP4 Error 1 for Satellite: 24343
# SGP4 Error 1 for Satellite: 22876
# SGP4 Error 1 for Satellite: 179
# SGP4 Error 1 for Satellite: 25947
# SGP4 Error 1 for Satellite: 24627
# SGP4 Error 1 for Satellite: 24831
# SGP4 Error 1 for Satellite: 24230
# SGP4 Error 1 for Satellite: 25905
# SGP4 Error 1 for Satellite: 4134
# SGP4 Error 1 for Satellite: 23887
# SGP4 Error 1 for Satellite: 26100
# SGP4 Error 1 for Satellite: 26099
# SGP4 Error 1 for Satellite: 26060
# SGP4 Error 1 for Satellite: 24481
# SGP4 Error 1 for Satellite: 24612
# SGP4 Error 1 for Satellite: 24233
# SGP4 Error 1 for Satellite: 18590
# SGP4 Error 1 for Satellite: 25965
# SGP4 Error 1 for Satellite: 15977
# SGP4 Error 1 for Satellite: 24389
# SGP4 Error 1 for Satellite: 24143
# SGP4 Error 1 for Satellite: 24314
# SGP4 Error 1 for Satellite: 24112
# SGP4 Error 1 for Satellite: 11331
# SGP4 Error 1 for Satellite: 20854
# SGP4 Error 1 for Satellite: 19028
# SGP4 Error 1 for Satellite: 24618
# SGP4 Error 1 for Satellite: 20919
# SGP4 Error 1 for Satellite: 17630
# SGP4 Error 1 for Satellite: 24358
# SGP4 Error 1 for Satellite: 24139
# SGP4 Error 1 for Satellite: 26112
# SGP4 Error 1 for Satellite: 22457
# SGP4 Error 1 for Satellite: 25393
# SGP4 Error 1 for Satellite: 24150
# SGP4 Error 1 for Satellite: 25709
# Month: 2000-03 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 26117
# SGP4 Error 1 for Satellite: 5714
# SGP4 Error 1 for Satellite: 24062
# SGP4 Error 1 for Satellite: 20966
# SGP4 Error 1 for Satellite: 24540
# SGP4 Error 1 for Satellite: 24342
# SGP4 Error 1 for Satellite: 20968
# SGP4 Error 1 for Satellite: 23417
# SGP4 Error 1 for Satellite: 25223
# SGP4 Error 1 for Satellite: 16084
# SGP4 Error 1 for Satellite: 25137
# SGP4 Error 1 for Satellite: 24686
# SGP4 Error 1 for Satellite: 19435
# SGP4 Error 1 for Satellite: 25056
# SGP4 Error 1 for Satellite: 22482
# SGP4 Error 1 for Satellite: 13577
# SGP4 Error 1 for Satellite: 26245
# SGP4 Error 1 for Satellite: 26244
# SGP4 Error 1 for Satellite: 15983
# SGP4 Error 1 for Satellite: 25249
# SGP4 Error 1 for Satellite: 25906
# SGP4 Error 1 for Satellite: 4601
# SGP4 Error 1 for Satellite: 5021
# SGP4 Error 1 for Satellite: 17201
# SGP4 Error 1 for Satellite: 22412
# SGP4 Error 1 for Satellite: 20704
# SGP4 Error 1 for Satellite: 22033
# SGP4 Error 1 for Satellite: 24153
# SGP4 Error 1 for Satellite: 26067
# SGP4 Error 1 for Satellite: 24033
# SGP4 Error 1 for Satellite: 26302
# SGP4 Error 1 for Satellite: 23834
# SGP4 Error 1 for Satellite: 24187
# Month: 2000-04 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 26355
# SGP4 Error 1 for Satellite: 23996
# SGP4 Error 1 for Satellite: 25033
# SGP4 Error 1 for Satellite: 4029
# SGP4 Error 1 for Satellite: 3962
# SGP4 Error 1 for Satellite: 17769
# SGP4 Error 1 for Satellite: 26085
# SGP4 Error 1 for Satellite: 24694
# SGP4 Error 1 for Satellite: 10135
# SGP4 Error 1 for Satellite: 26114
# SGP4 Error 1 for Satellite: 603
# SGP4 Error 1 for Satellite: 22580
# SGP4 Error 1 for Satellite: 12180
# SGP4 Error 1 for Satellite: 23098
# SGP4 Error 1 for Satellite: 24234
# SGP4 Error 1 for Satellite: 20338
# SGP4 Error 1 for Satellite: 22470
# SGP4 Error 1 for Satellite: 22726
# SGP4 Error 1 for Satellite: 25235
# SGP4 Error 1 for Satellite: 26363
# SGP4 Error 1 for Satellite: 24998
# Month: 2000-05 -> TLE DF size: 22
# SGP4 Error 1 for Satellite: 26371
# SGP4 Error 1 for Satellite: 24211
# SGP4 Error 1 for Satellite: 26240
# SGP4 Error 1 for Satellite: 21225
# SGP4 Error 1 for Satellite: 13576
# SGP4 Error 1 for Satellite: 23782
# SGP4 Error 1 for Satellite: 4985
# SGP4 Error 1 for Satellite: 4624
# SGP4 Error 1 for Satellite: 23858
# SGP4 Error 1 for Satellite: 24377
# SGP4 Error 1 for Satellite: 4006
# SGP4 Error 1 for Satellite: 14411
# SGP4 Error 1 for Satellite: 24093
# SGP4 Error 1 for Satellite: 10860
# SGP4 Error 1 for Satellite: 26116
# SGP4 Error 1 for Satellite: 22507
# SGP4 Error 1 for Satellite: 11629
# SGP4 Error 1 for Satellite: 3566
# SGP4 Error 1 for Satellite: 23502
# SGP4 Error 1 for Satellite: 24771
# SGP4 Error 1 for Satellite: 16934
# SGP4 Error 1 for Satellite: 26367
# SGP4 Error 1 for Satellite: 24147
# SGP4 Error 1 for Satellite: 24982
# SGP4 Error 1 for Satellite: 8092
# SGP4 Error 1 for Satellite: 17206
# SGP4 Error 1 for Satellite: 26380
# SGP4 Error 1 for Satellite: 24175
# SGP4 Error 1 for Satellite: 26379
# SGP4 Error 1 for Satellite: 11268
# SGP4 Error 1 for Satellite: 14555
# Month: 2000-06 -> TLE DF size: 32
# SGP4 Error 1 for Satellite: 1721
# SGP4 Error 1 for Satellite: 24262
# SGP4 Error 1 for Satellite: 26392
# SGP4 Error 1 for Satellite: 26391
# SGP4 Error 1 for Satellite: 21025
# SGP4 Error 1 for Satellite: 20339
# SGP4 Error 1 for Satellite: 26396
# SGP4 Error 1 for Satellite: 17256
# SGP4 Error 1 for Satellite: 26395
# SGP4 Error 1 for Satellite: 22402
# SGP4 Error 1 for Satellite: 24216
# SGP4 Error 1 for Satellite: 23209
# SGP4 Error 1 for Satellite: 24085
# SGP4 Error 1 for Satellite: 22542
# SGP4 Error 1 for Satellite: 25939
# SGP4 Error 1 for Satellite: 20698
# SGP4 Error 1 for Satellite: 26434
# SGP4 Error 1 for Satellite: 26401
# SGP4 Error 1 for Satellite: 9530
# SGP4 Error 1 for Satellite: 19390
# SGP4 Error 1 for Satellite: 2363
# SGP4 Error 1 for Satellite: 24878
# SGP4 Error 1 for Satellite: 18208
# SGP4 Error 1 for Satellite: 23050
# SGP4 Error 1 for Satellite: 26400
# SGP4 Error 1 for Satellite: 26357
# SGP4 Error 1 for Satellite: 25123
# SGP4 Error 1 for Satellite: 26437
# SGP4 Error 1 for Satellite: 26435
# SGP4 Error 1 for Satellite: 26418
# Month: 2000-07 -> TLE DF size: 33
# SGP4 Error 1 for Satellite: 25739
# SGP4 Error 1 for Satellite: 20869
# SGP4 Error 1 for Satellite: 24043
# SGP4 Error 1 for Satellite: 26440
# SGP4 Error 1 for Satellite: 24348
# SGP4 Error 1 for Satellite: 24189
# SGP4 Error 1 for Satellite: 15786
# SGP4 Error 1 for Satellite: 26364
# SGP4 Error 1 for Satellite: 26462
# SGP4 Error 6 for Satellite: 26465
# SGP4 Error 1 for Satellite: 26419
# SGP4 Error 1 for Satellite: 26420
# SGP4 Error 1 for Satellite: 26047
# SGP4 Error 1 for Satellite: 22540
# SGP4 Error 1 for Satellite: 24321
# SGP4 Error 1 for Satellite: 13967
# SGP4 Error 1 for Satellite: 23650
# SGP4 Error 1 for Satellite: 24190
# SGP4 Error 1 for Satellite: 21538
# SGP4 Error 1 for Satellite: 26361
# SGP4 Error 1 for Satellite: 21389
# SGP4 Error 1 for Satellite: 26468
# SGP4 Error 1 for Satellite: 22968
# SGP4 Error 1 for Satellite: 26478
# SGP4 Error 1 for Satellite: 26479
# SGP4 Error 1 for Satellite: 26472
# Month: 2000-08 -> TLE DF size: 26
# SGP4 Error 1 for Satellite: 23291
# SGP4 Error 1 for Satellite: 12547
# SGP4 Error 1 for Satellite: 26105
# SGP4 Error 1 for Satellite: 20399
# SGP4 Error 1 for Satellite: 23049
# SGP4 Error 1 for Satellite: 26136
# SGP4 Error 1 for Satellite: 23941
# SGP4 Error 1 for Satellite: 26485
# SGP4 Error 1 for Satellite: 26484
# SGP4 Error 1 for Satellite: 21690
# SGP4 Error 1 for Satellite: 10362
# SGP4 Error 1 for Satellite: 24032
# SGP4 Error 1 for Satellite: 24984
# SGP4 Error 1 for Satellite: 25180
# SGP4 Error 1 for Satellite: 13775
# SGP4 Error 1 for Satellite: 25813
# SGP4 Error 1 for Satellite: 25497
# SGP4 Error 1 for Satellite: 26456
# SGP4 Error 1 for Satellite: 5440
# SGP4 Error 1 for Satellite: 25310
# SGP4 Error 1 for Satellite: 26413
# SGP4 Error 1 for Satellite: 26491
# SGP4 Error 1 for Satellite: 26453
# SGP4 Error 1 for Satellite: 20021
# SGP4 Error 1 for Satellite: 26492
# SGP4 Error 1 for Satellite: 25995
# SGP4 Error 1 for Satellite: 14693
# SGP4 Error 1 for Satellite: 25737
# SGP4 Error 1 for Satellite: 26439
# SGP4 Error 1 for Satellite: 26493
# SGP4 Error 1 for Satellite: 11221
# SGP4 Error 1 for Satellite: 23210
# SGP4 Error 1 for Satellite: 26544
# SGP4 Error 1 for Satellite: 5070
# SGP4 Error 1 for Satellite: 24341
# SGP4 Error 1 for Satellite: 26149
# SGP4 Error 1 for Satellite: 24238
# Month: 2000-09 -> TLE DF size: 41
# SGP4 Error 1 for Satellite: 26403
# SGP4 Error 1 for Satellite: 26553
# SGP4 Error 1 for Satellite: 26556
# SGP4 Error 1 for Satellite: 26555
# SGP4 Error 1 for Satellite: 26104
# SGP4 Error 1 for Satellite: 18984
# SGP4 Error 1 for Satellite: 26138
# SGP4 Error 1 for Satellite: 25129
# SGP4 Error 1 for Satellite: 25547
# SGP4 Error 1 for Satellite: 21829
# SGP4 Error 1 for Satellite: 26542
# SGP4 Error 1 for Satellite: 23954
# SGP4 Error 1 for Satellite: 25234
# SGP4 Error 1 for Satellite: 26541
# SGP4 Error 1 for Satellite: 23971
# SGP4 Error 1 for Satellite: 26543
# SGP4 Error 1 for Satellite: 7967
# SGP4 Error 1 for Satellite: 26539
# SGP4 Error 1 for Satellite: 26540
# SGP4 Error 1 for Satellite: 26408
# SGP4 Error 1 for Satellite: 26568
# SGP4 Error 1 for Satellite: 26425
# SGP4 Error 1 for Satellite: 23632
# SGP4 Error 1 for Satellite: 26571
# SGP4 Error 1 for Satellite: 24249
# SGP4 Error 1 for Satellite: 23817
# SGP4 Error 1 for Satellite: 23107
# SGP4 Error 1 for Satellite: 25305
# SGP4 Error 1 for Satellite: 4930
# SGP4 Error 1 for Satellite: 4325
# SGP4 Error 1 for Satellite: 25390
# SGP4 Error 1 for Satellite: 24566
# SGP4 Error 1 for Satellite: 26144
# SGP4 Error 1 for Satellite: 26582
# SGP4 Error 1 for Satellite: 26301
# SGP4 Error 1 for Satellite: 24100
# SGP4 Error 1 for Satellite: 26581
# SGP4 Error 1 for Satellite: 23549
# SGP4 Error 1 for Satellite: 26584
# SGP4 Error 1 for Satellite: 25031
# SGP4 Error 1 for Satellite: 26133
# SGP4 Error 1 for Satellite: 26589
# SGP4 Error 1 for Satellite: 26587
# SGP4 Error 1 for Satellite: 26586
# SGP4 Error 1 for Satellite: 1937
# SGP4 Error 1 for Satellite: 26585
# SGP4 Error 6 for Satellite: 17208
# SGP4 Error 1 for Satellite: 26595
# SGP4 Error 1 for Satellite: 26592
# SGP4 Error 1 for Satellite: 26594
# SGP4 Error 1 for Satellite: 26597
# SGP4 Error 1 for Satellite: 26593
# SGP4 Error 1 for Satellite: 26596
# SGP4 Error 1 for Satellite: 26598
# SGP4 Error 1 for Satellite: 22384
# SGP4 Error 1 for Satellite: 23501
# SGP4 Error 1 for Satellite: 26438
# SGP4 Error 1 for Satellite: 26461
# Month: 2000-10 -> TLE DF size: 62
# SGP4 Error 1 for Satellite: 26572
# SGP4 Error 1 for Satellite: 26604
# SGP4 Error 1 for Satellite: 24258
# SGP4 Error 1 for Satellite: 26167
# SGP4 Error 1 for Satellite: 15781
# SGP4 Error 1 for Satellite: 26431
# SGP4 Error 1 for Satellite: 25069
# SGP4 Error 1 for Satellite: 5077
# SGP4 Error 1 for Satellite: 26206
# SGP4 Error 1 for Satellite: 16311
# SGP4 Error 1 for Satellite: 23635
# SGP4 Error 1 for Satellite: 26340
# SGP4 Error 1 for Satellite: 26274
# SGP4 Error 1 for Satellite: 25032
# SGP4 Error 1 for Satellite: 8979
# SGP4 Error 1 for Satellite: 20255
# SGP4 Error 6 for Satellite: 18963
# SGP4 Error 1 for Satellite: 24116
# SGP4 Error 1 for Satellite: 20896
# SGP4 Error 1 for Satellite: 2167
# SGP4 Error 1 for Satellite: 26170
# SGP4 Error 1 for Satellite: 26552
# SGP4 Error 1 for Satellite: 21802
# SGP4 Error 1 for Satellite: 26616
# SGP4 Error 1 for Satellite: 24117
# SGP4 Error 1 for Satellite: 3492
# SGP4 Error 1 for Satellite: 17726
# SGP4 Error 1 for Satellite: 23824
# SGP4 Error 1 for Satellite: 26618
# SGP4 Error 1 for Satellite: 4625
# SGP4 Error 1 for Satellite: 26455
# SGP4 Error 1 for Satellite: 22373
# SGP4 Error 1 for Satellite: 25470
# SGP4 Error 1 for Satellite: 24164
# Month: 2000-11 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 26171
# SGP4 Error 1 for Satellite: 26190
# SGP4 Error 1 for Satellite: 26627
# SGP4 Error 1 for Satellite: 26628
# SGP4 Error 1 for Satellite: 21334
# SGP4 Error 1 for Satellite: 8577
# SGP4 Error 1 for Satellite: 10212
# SGP4 Error 1 for Satellite: 26164
# SGP4 Error 1 for Satellite: 22380
# SGP4 Error 1 for Satellite: 26630
# SGP4 Error 1 for Satellite: 26417
# SGP4 Error 1 for Satellite: 24743
# SGP4 Error 1 for Satellite: 25124
# SGP4 Error 1 for Satellite: 25422
# SGP4 Error 1 for Satellite: 23848
# SGP4 Error 1 for Satellite: 23579
# SGP4 Error 1 for Satellite: 20635
# SGP4 Error 1 for Satellite: 20335
# SGP4 Error 1 for Satellite: 17845
# SGP4 Error 1 for Satellite: 17628
# SGP4 Error 1 for Satellite: 16480
# SGP4 Error 1 for Satellite: 26433
# SGP4 Error 1 for Satellite: 22067
# SGP4 Error 1 for Satellite: 19830
# SGP4 Error 1 for Satellite: 24221
# SGP4 Error 1 for Satellite: 18719
# SGP4 Error 1 for Satellite: 4618
# SGP4 Error 1 for Satellite: 24140
# SGP4 Error 1 for Satellite: 15538
# SGP4 Error 1 for Satellite: 26051
# SGP4 Error 1 for Satellite: 26153
# SGP4 Error 1 for Satellite: 24429
# SGP4 Error 1 for Satellite: 24089
# SGP4 Error 1 for Satellite: 24154
# SGP4 Error 1 for Satellite: 4392
# SGP4 Error 1 for Satellite: 26252
# SGP4 Error 1 for Satellite: 25529
# SGP4 Error 1 for Satellite: 24181
# SGP4 Error 1 for Satellite: 25553
# Month: 2000-12 -> TLE DF size: 41
# SGP4 Error 1 for Satellite: 4584
# SGP4 Error 1 for Satellite: 23854
# SGP4 Error 1 for Satellite: 22465
# SGP4 Error 1 for Satellite: 22925
# SGP4 Error 1 for Satellite: 26655
# SGP4 Error 1 for Satellite: 26318
# SGP4 Error 1 for Satellite: 26458
# SGP4 Error 1 for Satellite: 26667
# SGP4 Error 1 for Satellite: 4647
# SGP4 Error 1 for Satellite: 16243
# SGP4 Error 1 for Satellite: 12196
# SGP4 Error 1 for Satellite: 24745
# SGP4 Error 1 for Satellite: 22659
# SGP4 Error 1 for Satellite: 26421
# SGP4 Error 1 for Satellite: 26342
# SGP4 Error 1 for Satellite: 16110
# SGP4 Error 1 for Satellite: 26325
# SGP4 Error 1 for Satellite: 26223
# SGP4 Error 1 for Satellite: 26664
# SGP4 Error 1 for Satellite: 15758
# SGP4 Error 1 for Satellite: 26665
# SGP4 Error 1 for Satellite: 23982
# SGP4 Error 1 for Satellite: 26499
# SGP4 Error 1 for Satellite: 22452
# SGP4 Error 1 for Satellite: 24455
# SGP4 Error 1 for Satellite: 14915
# SGP4 Error 1 for Satellite: 14520
# SGP4 Error 1 for Satellite: 25576
# SGP4 Error 1 for Satellite: 26689
# SGP4 Error 1 for Satellite: 20456
# SGP4 Error 1 for Satellite: 24176
# SGP4 Error 1 for Satellite: 26570
# SGP4 Error 1 for Satellite: 24361
# SGP4 Error 1 for Satellite: 26688
# Month: 2001-01 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 26263
# SGP4 Error 1 for Satellite: 23976
# SGP4 Error 1 for Satellite: 25313
# SGP4 Error 1 for Satellite: 25451
# SGP4 Error 1 for Satellite: 26649
# SGP4 Error 1 for Satellite: 26663
# SGP4 Error 1 for Satellite: 26097
# SGP4 Error 1 for Satellite: 26303
# SGP4 Error 1 for Satellite: 26606
# SGP4 Error 1 for Satellite: 26615
# SGP4 Error 1 for Satellite: 25076
# SGP4 Error 1 for Satellite: 3560
# SGP4 Error 1 for Satellite: 8432
# SGP4 Error 1 for Satellite: 3687
# SGP4 Error 1 for Satellite: 26537
# SGP4 Error 1 for Satellite: 23419
# SGP4 Error 1 for Satellite: 22986
# SGP4 Error 1 for Satellite: 25720
# SGP4 Error 1 for Satellite: 25314
# SGP4 Error 1 for Satellite: 26600
# SGP4 Error 1 for Satellite: 16125
# SGP4 Error 1 for Satellite: 26698
# SGP4 Error 1 for Satellite: 20094
# SGP4 Error 1 for Satellite: 16112
# SGP4 Error 1 for Satellite: 26328
# SGP4 Error 1 for Satellite: 26710
# SGP4 Error 1 for Satellite: 25424
# SGP4 Error 1 for Satellite: 26714
# Month: 2001-02 -> TLE DF size: 28
# SGP4 Error 1 for Satellite: 26712
# SGP4 Error 1 for Satellite: 22521
# SGP4 Error 1 for Satellite: 26704
# SGP4 Error 1 for Satellite: 23019
# SGP4 Error 1 for Satellite: 26709
# SGP4 Error 1 for Satellite: 26705
# SGP4 Error 1 for Satellite: 26062
# SGP4 Error 1 for Satellite: 17152
# SGP4 Error 1 for Satellite: 4215
# SGP4 Error 1 for Satellite: 26706
# SGP4 Error 1 for Satellite: 26327
# SGP4 Error 1 for Satellite: 4620
# SGP4 Error 1 for Satellite: 4623
# SGP4 Error 1 for Satellite: 26707
# SGP4 Error 1 for Satellite: 9968
# SGP4 Error 1 for Satellite: 22466
# SGP4 Error 1 for Satellite: 26399
# SGP4 Error 1 for Satellite: 26691
# SGP4 Error 1 for Satellite: 24217
# SGP4 Error 1 for Satellite: 24441
# SGP4 Error 1 for Satellite: 16609
# SGP4 Error 1 for Satellite: 26059
# SGP4 Error 1 for Satellite: 22233
# SGP4 Error 1 for Satellite: 25734
# SGP4 Error 1 for Satellite: 26173
# SGP4 Error 1 for Satellite: 23951
# SGP4 Error 1 for Satellite: 26177
# SGP4 Error 1 for Satellite: 23029
# SGP4 Error 1 for Satellite: 24385
# SGP4 Error 1 for Satellite: 25013
# SGP4 Error 1 for Satellite: 462
# Month: 2001-03 -> TLE DF size: 38
# SGP4 Error 1 for Satellite: 25554
# SGP4 Error 1 for Satellite: 19733
# SGP4 Error 1 for Satellite: 21840
# SGP4 Error 1 for Satellite: 26271
# SGP4 Error 1 for Satellite: 23133
# SGP4 Error 1 for Satellite: 23281
# SGP4 Error 1 for Satellite: 20471
# SGP4 Error 1 for Satellite: 26249
# SGP4 Error 1 for Satellite: 26258
# SGP4 Error 1 for Satellite: 24099
# SGP4 Error 1 for Satellite: 26176
# SGP4 Error 1 for Satellite: 26161
# SGP4 Error 1 for Satellite: 26210
# SGP4 Error 1 for Satellite: 17988
# SGP4 Error 1 for Satellite: 25392
# SGP4 Error 1 for Satellite: 26730
# SGP4 Error 1 for Satellite: 5034
# SGP4 Error 1 for Satellite: 15553
# SGP4 Error 1 for Satellite: 26713
# SGP4 Error 1 for Satellite: 15957
# SGP4 Error 1 for Satellite: 5143
# SGP4 Error 1 for Satellite: 26538
# SGP4 Error 1 for Satellite: 21841
# SGP4 Error 1 for Satellite: 26748
# SGP4 Error 1 for Satellite: 16547
# SGP4 Error 1 for Satellite: 24359
# SGP4 Error 1 for Satellite: 16546
# SGP4 Error 1 for Satellite: 24204
# SGP4 Error 1 for Satellite: 26653
# SGP4 Error 1 for Satellite: 10960
# SGP4 Error 1 for Satellite: 26750
# SGP4 Error 1 for Satellite: 647
# Month: 2001-04 -> TLE DF size: 33
# SGP4 Error 1 for Satellite: 26747
# SGP4 Error 1 for Satellite: 26354
# SGP4 Error 1 for Satellite: 26603
# SGP4 Error 1 for Satellite: 25107
# SGP4 Error 1 for Satellite: 15027
# SGP4 Error 1 for Satellite: 26319
# SGP4 Error 1 for Satellite: 16235
# SGP4 Error 1 for Satellite: 11458
# SGP4 Error 1 for Satellite: 26768
# SGP4 Error 1 for Satellite: 26767
# SGP4 Error 1 for Satellite: 14313
# SGP4 Error 1 for Satellite: 26774
# SGP4 Error 1 for Satellite: 26502
# SGP4 Error 1 for Satellite: 11252
# SGP4 Error 1 for Satellite: 20614
# SGP4 Error 1 for Satellite: 26255
# SGP4 Error 1 for Satellite: 26424
# SGP4 Error 1 for Satellite: 17094
# Month: 2001-05 -> TLE DF size: 18
# SGP4 Error 1 for Satellite: 26776
# SGP4 Error 1 for Satellite: 26723
# SGP4 Error 1 for Satellite: 23518
# SGP4 Error 1 for Satellite: 24337
# SGP4 Error 1 for Satellite: 23989
# SGP4 Error 1 for Satellite: 7487
# SGP4 Error 1 for Satellite: 6085
# SGP4 Error 1 for Satellite: 8298
# SGP4 Error 1 for Satellite: 3524
# SGP4 Error 1 for Satellite: 17471
# SGP4 Error 1 for Satellite: 26856
# SGP4 Error 1 for Satellite: 26854
# SGP4 Error 1 for Satellite: 26447
# SGP4 Error 1 for Satellite: 24000
# SGP4 Error 1 for Satellite: 24247
# SGP4 Error 1 for Satellite: 26457
# SGP4 Error 1 for Satellite: 22424
# SGP4 Error 1 for Satellite: 20611
# SGP4 Error 1 for Satellite: 1347
# SGP4 Error 1 for Satellite: 19641
# SGP4 Error 1 for Satellite: 24158
# Month: 2001-06 -> TLE DF size: 21
# SGP4 Error 1 for Satellite: 3467
# SGP4 Error 1 for Satellite: 18980
# SGP4 Error 1 for Satellite: 25361
# SGP4 Error 1 for Satellite: 4726
# SGP4 Error 1 for Satellite: 26860
# SGP4 Error 1 for Satellite: 26739
# SGP4 Error 1 for Satellite: 26335
# SGP4 Error 1 for Satellite: 26337
# SGP4 Error 1 for Satellite: 23099
# SGP4 Error 1 for Satellite: 24767
# SGP4 Error 1 for Satellite: 26334
# SGP4 Error 1 for Satellite: 12750
# SGP4 Error 1 for Satellite: 16939
# SGP4 Error 1 for Satellite: 10181
# SGP4 Error 1 for Satellite: 2496
# SGP4 Error 1 for Satellite: 22048
# SGP4 Error 1 for Satellite: 26314
# SGP4 Error 1 for Satellite: 24323
# SGP4 Error 1 for Satellite: 26869
# Month: 2001-07 -> TLE DF size: 21
# SGP4 Error 1 for Satellite: 22933
# SGP4 Error 1 for Satellite: 26879
# SGP4 Error 1 for Satellite: 23071
# SGP4 Error 1 for Satellite: 23172
# SGP4 Error 1 for Satellite: 26295
# SGP4 Error 1 for Satellite: 23517
# SGP4 Error 1 for Satellite: 11266
# SGP4 Error 1 for Satellite: 20612
# SGP4 Error 1 for Satellite: 26868
# SGP4 Error 1 for Satellite: 4940
# SGP4 Error 1 for Satellite: 3683
# SGP4 Error 1 for Satellite: 26404
# SGP4 Error 1 for Satellite: 24976
# SGP4 Error 1 for Satellite: 26888
# SGP4 Error 1 for Satellite: 26773
# SGP4 Error 1 for Satellite: 24184
# SGP4 Error 1 for Satellite: 26891
# SGP4 Error 1 for Satellite: 16545
# SGP4 Error 1 for Satellite: 15955
# SGP4 Error 1 for Satellite: 26687
# SGP4 Error 1 for Satellite: 22467
# SGP4 Error 1 for Satellite: 26894
# SGP4 Error 1 for Satellite: 25070
# SGP4 Error 1 for Satellite: 26893
# SGP4 Error 1 for Satellite: 26902
# SGP4 Error 1 for Satellite: 26903
# SGP4 Error 1 for Satellite: 18127
# SGP4 Error 1 for Satellite: 25555
# SGP4 Error 1 for Satellite: 23630
# SGP4 Error 1 for Satellite: 25121
# Month: 2001-08 -> TLE DF size: 33
# SGP4 Error 6 for Satellite: 24311
# SGP4 Error 6 for Satellite: 23481
# SGP4 Error 1 for Satellite: 11777
# SGP4 Error 1 for Satellite: 8128
# SGP4 Error 1 for Satellite: 24068
# SGP4 Error 1 for Satellite: 15778
# SGP4 Error 1 for Satellite: 14236
# SGP4 Error 1 for Satellite: 24704
# SGP4 Error 1 for Satellite: 26909
# SGP4 Error 1 for Satellite: 17703
# SGP4 Error 1 for Satellite: 20224
# SGP4 Error 1 for Satellite: 10561
# SGP4 Error 1 for Satellite: 24172
# SGP4 Error 1 for Satellite: 26711
# SGP4 Error 1 for Satellite: 25557
# SGP4 Error 1 for Satellite: 21658
# SGP4 Error 1 for Satellite: 19055
# SGP4 Error 1 for Satellite: 26282
# SGP4 Error 1 for Satellite: 25648
# SGP4 Error 1 for Satellite: 26912
# SGP4 Error 1 for Satellite: 24106
# SGP4 Error 1 for Satellite: 23430
# SGP4 Error 1 for Satellite: 26908
# SGP4 Error 1 for Satellite: 25674
# SGP4 Error 1 for Satellite: 21837
# SGP4 Error 1 for Satellite: 23835
# SGP4 Error 1 for Satellite: 23117
# SGP4 Error 1 for Satellite: 21945
# SGP4 Error 1 for Satellite: 24146
# SGP4 Error 1 for Satellite: 22560
# SGP4 Error 1 for Satellite: 18983
# Month: 2001-09 -> TLE DF size: 31
# SGP4 Error 1 for Satellite: 21080
# SGP4 Error 1 for Satellite: 20960
# SGP4 Error 1 for Satellite: 25428
# SGP4 Error 1 for Satellite: 20914
# SGP4 Error 1 for Satellite: 24016
# SGP4 Error 1 for Satellite: 22250
# SGP4 Error 1 for Satellite: 21838
# SGP4 Error 1 for Satellite: 26933
# SGP4 Error 1 for Satellite: 26938
# SGP4 Error 1 for Satellite: 26825
# SGP4 Error 1 for Satellite: 26937
# SGP4 Error 1 for Satellite: 26775
# SGP4 Error 1 for Satellite: 26943
# SGP4 Error 1 for Satellite: 4983
# SGP4 Error 1 for Satellite: 24122
# SGP4 Error 1 for Satellite: 26947
# SGP4 Error 1 for Satellite: 26942
# SGP4 Error 1 for Satellite: 26950
# SGP4 Error 1 for Satellite: 5520
# SGP4 Error 1 for Satellite: 12886
# SGP4 Error 1 for Satellite: 23743
# SGP4 Error 1 for Satellite: 26881
# SGP4 Error 1 for Satellite: 5328
# SGP4 Error 1 for Satellite: 21839
# SGP4 Error 1 for Satellite: 24174
# SGP4 Error 1 for Satellite: 20851
# SGP4 Error 1 for Satellite: 26450
# SGP4 Error 1 for Satellite: 12201
# SGP4 Error 1 for Satellite: 19010
# SGP4 Error 1 for Satellite: 13459
# SGP4 Error 1 for Satellite: 26946
# SGP4 Error 1 for Satellite: 26944
# SGP4 Error 1 for Satellite: 13985
# SGP4 Error 1 for Satellite: 24466
# SGP4 Error 1 for Satellite: 26445
# SGP4 Error 1 for Satellite: 26945
# SGP4 Error 1 for Satellite: 26771
# SGP4 Error 1 for Satellite: 22846
# SGP4 Error 1 for Satellite: 12208
# SGP4 Error 1 for Satellite: 26956
# SGP4 Error 1 for Satellite: 3523
# SGP4 Error 1 for Satellite: 22172
# SGP4 Error 1 for Satellite: 24515
# SGP4 Error 1 for Satellite: 26954
# SGP4 Error 1 for Satellite: 26951
# SGP4 Error 1 for Satellite: 4862
# SGP4 Error 1 for Satellite: 26174
# SGP4 Error 1 for Satellite: 24628
# SGP4 Error 1 for Satellite: 25200
# SGP4 Error 1 for Satellite: 26952
# SGP4 Error 1 for Satellite: 24517
# SGP4 Error 1 for Satellite: 22385
# SGP4 Error 1 for Satellite: 18745
# SGP4 Error 1 for Satellite: 17120
# SGP4 Error 1 for Satellite: 14516
# SGP4 Error 1 for Satellite: 24207
# SGP4 Error 1 for Satellite: 10493
# SGP4 Error 1 for Satellite: 26749
# SGP4 Error 1 for Satellite: 3361
# SGP4 Error 1 for Satellite: 7867
# Month: 2001-10 -> TLE DF size: 63
# SGP4 Error 1 for Satellite: 26878
# SGP4 Error 1 for Satellite: 17154
# SGP4 Error 1 for Satellite: 24107
# SGP4 Error 1 for Satellite: 23631
# SGP4 Error 1 for Satellite: 26250
# SGP4 Error 1 for Satellite: 26248
# SGP4 Error 1 for Satellite: 5198
# SGP4 Error 1 for Satellite: 26237
# SGP4 Error 1 for Satellite: 1944
# SGP4 Error 1 for Satellite: 18159
# SGP4 Error 1 for Satellite: 19482
# SGP4 Error 1 for Satellite: 21491
# SGP4 Error 1 for Satellite: 26972
# SGP4 Error 1 for Satellite: 17184
# SGP4 Error 1 for Satellite: 20880
# SGP4 Error 1 for Satellite: 24585
# SGP4 Error 1 for Satellite: 15552
# SGP4 Error 1 for Satellite: 26890
# SGP4 Error 1 for Satellite: 19220
# SGP4 Error 1 for Satellite: 23740
# SGP4 Error 1 for Satellite: 24149
# SGP4 Error 1 for Satellite: 26963
# SGP4 Error 1 for Satellite: 26427
# SGP4 Error 1 for Satellite: 11155
# SGP4 Error 1 for Satellite: 26971
# SGP4 Error 1 for Satellite: 26984
# SGP4 Error 1 for Satellite: 16878
# SGP4 Error 1 for Satellite: 26204
# Month: 2001-11 -> TLE DF size: 31
# SGP4 Error 1 for Satellite: 275
# SGP4 Error 1 for Satellite: 26990
# SGP4 Error 1 for Satellite: 26991
# SGP4 Error 1 for Satellite: 21867
# SGP4 Error 1 for Satellite: 24317
# SGP4 Error 1 for Satellite: 26875
# SGP4 Error 1 for Satellite: 26877
# SGP4 Error 1 for Satellite: 24259
# SGP4 Error 1 for Satellite: 25155
# SGP4 Error 1 for Satellite: 20610
# SGP4 Error 1 for Satellite: 11216
# SGP4 Error 1 for Satellite: 17123
# SGP4 Error 1 for Satellite: 26935
# SGP4 Error 1 for Satellite: 19108
# SGP4 Error 1 for Satellite: 24014
# SGP4 Error 1 for Satellite: 25556
# SGP4 Error 1 for Satellite: 24339
# SGP4 Error 1 for Satellite: 27019
# SGP4 Error 1 for Satellite: 27011
# SGP4 Error 1 for Satellite: 27020
# SGP4 Error 1 for Satellite: 5591
# SGP4 Error 1 for Satellite: 27014
# SGP4 Error 1 for Satellite: 20052
# SGP4 Error 1 for Satellite: 27012
# SGP4 Error 1 for Satellite: 24199
# SGP4 Error 1 for Satellite: 26426
# SGP4 Error 1 for Satellite: 27010
# SGP4 Error 1 for Satellite: 26995
# SGP4 Error 1 for Satellite: 5981
# SGP4 Error 1 for Satellite: 26797
# SGP4 Error 1 for Satellite: 24318
# SGP4 Error 1 for Satellite: 27054
# SGP4 Error 1 for Satellite: 13446
# SGP4 Error 1 for Satellite: 27023
# SGP4 Error 1 for Satellite: 27017
# SGP4 Error 1 for Satellite: 4802
# SGP4 Error 1 for Satellite: 27013
# SGP4 Error 1 for Satellite: 27009
# SGP4 Error 1 for Satellite: 27018
# SGP4 Error 1 for Satellite: 22298
# SGP4 Error 1 for Satellite: 27021
# SGP4 Error 1 for Satellite: 3717
# SGP4 Error 1 for Satellite: 27015
# SGP4 Error 1 for Satellite: 21267
# SGP4 Error 1 for Satellite: 26201
# SGP4 Error 1 for Satellite: 24133
# SGP4 Error 1 for Satellite: 27062
# SGP4 Error 1 for Satellite: 26501
# SGP4 Error 1 for Satellite: 4944
# SGP4 Error 1 for Satellite: 24766
# Month: 2001-12 -> TLE DF size: 55
# SGP4 Error 1 for Satellite: 12702
# SGP4 Error 1 for Satellite: 26999
# SGP4 Error 1 for Satellite: 26966
# SGP4 Error 1 for Satellite: 24134
# SGP4 Error 1 for Satellite: 9828
# SGP4 Error 1 for Satellite: 27024
# SGP4 Error 1 for Satellite: 22660
# SGP4 Error 1 for Satellite: 26316
# SGP4 Error 1 for Satellite: 23733
# SGP4 Error 1 for Satellite: 20307
# SGP4 Error 1 for Satellite: 11932
# SGP4 Error 1 for Satellite: 13432
# SGP4 Error 1 for Satellite: 25191
# SGP4 Error 1 for Satellite: 27166
# SGP4 Error 1 for Satellite: 14319
# SGP4 Error 1 for Satellite: 27182
# SGP4 Error 1 for Satellite: 8309
# SGP4 Error 1 for Satellite: 14505
# SGP4 Error 1 for Satellite: 18511
# SGP4 Error 1 for Satellite: 11056
# SGP4 Error 1 for Satellite: 1673
# SGP4 Error 1 for Satellite: 27199
# SGP4 Error 1 for Satellite: 5759
# SGP4 Error 1 for Satellite: 27016
# SGP4 Error 1 for Satellite: 22372
# SGP4 Error 1 for Satellite: 27312
# SGP4 Error 1 for Satellite: 27176
# SGP4 Error 1 for Satellite: 24132
# SGP4 Error 1 for Satellite: 27313
# SGP4 Error 1 for Satellite: 26625
# SGP4 Error 1 for Satellite: 27339
# SGP4 Error 1 for Satellite: 27209
# SGP4 Error 1 for Satellite: 27288
# SGP4 Error 1 for Satellite: 27276
# SGP4 Error 1 for Satellite: 27274
# SGP4 Error 1 for Satellite: 26279
# SGP4 Error 1 for Satellite: 26660
# SGP4 Error 1 for Satellite: 22013
# SGP4 Error 1 for Satellite: 26925
# SGP4 Error 1 for Satellite: 26872
# SGP4 Error 1 for Satellite: 27214
# SGP4 Error 1 for Satellite: 26784
# SGP4 Error 1 for Satellite: 26889
# SGP4 Error 1 for Satellite: 27356
# SGP4 Error 1 for Satellite: 24179
# SGP4 Error 1 for Satellite: 27314
# SGP4 Error 1 for Satellite: 21987
# SGP4 Error 1 for Satellite: 3342
# SGP4 Error 1 for Satellite: 18678
# Month: 2002-01 -> TLE DF size: 53
# SGP4 Error 1 for Satellite: 24947
# SGP4 Error 1 for Satellite: 25988
# SGP4 Error 1 for Satellite: 11556
# SGP4 Error 1 for Satellite: 24736
# SGP4 Error 1 for Satellite: 27325
# SGP4 Error 1 for Satellite: 27335
# SGP4 Error 1 for Satellite: 26820
# SGP4 Error 1 for Satellite: 19541
# SGP4 Error 1 for Satellite: 27357
# SGP4 Error 1 for Satellite: 27277
# SGP4 Error 1 for Satellite: 27257
# SGP4 Error 1 for Satellite: 27278
# SGP4 Error 1 for Satellite: 22556
# SGP4 Error 1 for Satellite: 27282
# SGP4 Error 1 for Satellite: 27301
# SGP4 Error 1 for Satellite: 27197
# SGP4 Error 1 for Satellite: 27328
# SGP4 Error 1 for Satellite: 24191
# SGP4 Error 1 for Satellite: 27350
# SGP4 Error 1 for Satellite: 27220
# SGP4 Error 1 for Satellite: 27340
# SGP4 Error 1 for Satellite: 6221
# SGP4 Error 1 for Satellite: 23009
# SGP4 Error 1 for Satellite: 27344
# SGP4 Error 1 for Satellite: 21141
# SGP4 Error 1 for Satellite: 27359
# SGP4 Error 1 for Satellite: 24261
# SGP4 Error 1 for Satellite: 27201
# SGP4 Error 1 for Satellite: 27256
# SGP4 Error 1 for Satellite: 25498
# SGP4 Error 1 for Satellite: 13772
# SGP4 Error 1 for Satellite: 27261
# SGP4 Error 1 for Satellite: 4210
# SGP4 Error 1 for Satellite: 661
# SGP4 Error 1 for Satellite: 19544
# SGP4 Error 1 for Satellite: 7855
# SGP4 Error 1 for Satellite: 11269
# SGP4 Error 1 for Satellite: 27326
# SGP4 Error 1 for Satellite: 22427
# SGP4 Error 1 for Satellite: 1843
# SGP4 Error 1 for Satellite: 27364
# SGP4 Error 1 for Satellite: 27170
# SGP4 Error 1 for Satellite: 23460
# SGP4 Error 1 for Satellite: 11600
# SGP4 Error 1 for Satellite: 27264
# SGP4 Error 1 for Satellite: 27300
# SGP4 Error 1 for Satellite: 27341
# SGP4 Error 1 for Satellite: 27232
# SGP4 Error 1 for Satellite: 27262
# SGP4 Error 1 for Satellite: 27343
# SGP4 Error 1 for Satellite: 27366
# SGP4 Error 1 for Satellite: 27212
# SGP4 Error 1 for Satellite: 27321
# SGP4 Error 1 for Satellite: 27280
# SGP4 Error 1 for Satellite: 27243
# SGP4 Error 1 for Satellite: 27195
# SGP4 Error 1 for Satellite: 27167
# SGP4 Error 1 for Satellite: 27293
# SGP4 Error 1 for Satellite: 26752
# SGP4 Error 1 for Satellite: 27008
# SGP4 Error 1 for Satellite: 4976
# SGP4 Error 1 for Satellite: 27228
# SGP4 Error 1 for Satellite: 24779
# SGP4 Error 1 for Satellite: 19301
# SGP4 Error 1 for Satellite: 17031
# SGP4 Error 1 for Satellite: 27336
# SGP4 Error 1 for Satellite: 26312
# SGP4 Error 1 for Satellite: 27244
# SGP4 Error 1 for Satellite: 27383
# Month: 2002-02 -> TLE DF size: 70
# SGP4 Error 1 for Satellite: 27327
# SGP4 Error 1 for Satellite: 4015
# SGP4 Error 1 for Satellite: 27233
# SGP4 Error 1 for Satellite: 27206
# SGP4 Error 1 for Satellite: 27292
# SGP4 Error 1 for Satellite: 27183
# SGP4 Error 1 for Satellite: 24981
# SGP4 Error 1 for Satellite: 27318
# SGP4 Error 1 for Satellite: 26673
# SGP4 Error 1 for Satellite: 24242
# SGP4 Error 1 for Satellite: 24130
# SGP4 Error 1 for Satellite: 27284
# SGP4 Error 1 for Satellite: 12267
# SGP4 Error 1 for Satellite: 27349
# SGP4 Error 1 for Satellite: 27253
# SGP4 Error 1 for Satellite: 24198
# SGP4 Error 1 for Satellite: 27200
# SGP4 Error 1 for Satellite: 20651
# SGP4 Error 1 for Satellite: 27120
# SGP4 Error 1 for Satellite: 17116
# SGP4 Error 1 for Satellite: 24135
# SGP4 Error 1 for Satellite: 19300
# SGP4 Error 1 for Satellite: 27112
# SGP4 Error 1 for Satellite: 27258
# SGP4 Error 1 for Satellite: 19189
# SGP4 Error 1 for Satellite: 23742
# SGP4 Error 1 for Satellite: 26757
# SGP4 Error 1 for Satellite: 27348
# SGP4 Error 1 for Satellite: 19319
# SGP4 Error 1 for Satellite: 27204
# SGP4 Error 1 for Satellite: 26910
# SGP4 Error 1 for Satellite: 27311
# SGP4 Error 1 for Satellite: 15811
# SGP4 Error 1 for Satellite: 27290
# SGP4 Error 1 for Satellite: 27196
# SGP4 Error 1 for Satellite: 24081
# SGP4 Error 1 for Satellite: 27184
# SGP4 Error 1 for Satellite: 26983
# SGP4 Error 1 for Satellite: 27279
# SGP4 Error 1 for Satellite: 26744
# SGP4 Error 1 for Satellite: 27308
# SGP4 Error 1 for Satellite: 27283
# SGP4 Error 1 for Satellite: 27396
# SGP4 Error 1 for Satellite: 27272
# SGP4 Error 1 for Satellite: 27302
# SGP4 Error 1 for Satellite: 27189
# SGP4 Error 1 for Satellite: 26148
# SGP4 Error 1 for Satellite: 25018
# SGP4 Error 1 for Satellite: 27122
# SGP4 Error 1 for Satellite: 27393
# SGP4 Error 1 for Satellite: 15679
# SGP4 Error 1 for Satellite: 27185
# SGP4 Error 1 for Satellite: 21298
# SGP4 Error 1 for Satellite: 27355
# SGP4 Error 1 for Satellite: 23749
# Month: 2002-03 -> TLE DF size: 64
# SGP4 Error 1 for Satellite: 27332
# SGP4 Error 1 for Satellite: 27398
# SGP4 Error 1 for Satellite: 23767
# SGP4 Error 1 for Satellite: 26046
# SGP4 Error 1 for Satellite: 27221
# SGP4 Error 1 for Satellite: 24136
# SGP4 Error 1 for Satellite: 27227
# SGP4 Error 1 for Satellite: 27358
# SGP4 Error 1 for Satellite: 19358
# SGP4 Error 1 for Satellite: 22780
# SGP4 Error 1 for Satellite: 27079
# SGP4 Error 1 for Satellite: 27333
# SGP4 Error 1 for Satellite: 24645
# SGP4 Error 1 for Satellite: 24788
# SGP4 Error 1 for Satellite: 26216
# SGP4 Error 1 for Satellite: 27296
# SGP4 Error 1 for Satellite: 17110
# SGP4 Error 1 for Satellite: 27266
# SGP4 Error 1 for Satellite: 27303
# SGP4 Error 1 for Satellite: 23999
# SGP4 Error 1 for Satellite: 27186
# SGP4 Error 1 for Satellite: 14911
# SGP4 Error 1 for Satellite: 27202
# SGP4 Error 1 for Satellite: 5724
# SGP4 Error 1 for Satellite: 27265
# SGP4 Error 1 for Satellite: 27207
# SGP4 Error 1 for Satellite: 27191
# SGP4 Error 1 for Satellite: 27351
# SGP4 Error 1 for Satellite: 135
# SGP4 Error 1 for Satellite: 27192
# SGP4 Error 1 for Satellite: 4201
# SGP4 Error 1 for Satellite: 27362
# SGP4 Error 1 for Satellite: 27281
# SGP4 Error 1 for Satellite: 27188
# SGP4 Error 1 for Satellite: 21323
# SGP4 Error 1 for Satellite: 27190
# SGP4 Error 1 for Satellite: 27072
# SGP4 Error 1 for Satellite: 27411
# SGP4 Error 1 for Satellite: 27361
# SGP4 Error 1 for Satellite: 27413
# SGP4 Error 1 for Satellite: 25987
# SGP4 Error 1 for Satellite: 27139
# SGP4 Error 1 for Satellite: 26941
# SGP4 Error 1 for Satellite: 26466
# SGP4 Error 1 for Satellite: 27175
# SGP4 Error 1 for Satellite: 4899
# SGP4 Error 1 for Satellite: 25389
# SGP4 Error 1 for Satellite: 26183
# SGP4 Error 1 for Satellite: 27174
# SGP4 Error 1 for Satellite: 27203
# SGP4 Error 1 for Satellite: 27324
# SGP4 Error 1 for Satellite: 8155
# SGP4 Error 1 for Satellite: 27230
# SGP4 Error 1 for Satellite: 26996
# SGP4 Error 1 for Satellite: 27417
# SGP4 Error 1 for Satellite: 27252
# SGP4 Error 1 for Satellite: 11821
# SGP4 Error 1 for Satellite: 27410
# SGP4 Error 1 for Satellite: 27294
# SGP4 Error 1 for Satellite: 27346
# SGP4 Error 1 for Satellite: 10226
# Month: 2002-04 -> TLE DF size: 65
# SGP4 Error 1 for Satellite: 27229
# SGP4 Error 1 for Satellite: 26290
# SGP4 Error 1 for Satellite: 27394
# SGP4 Error 1 for Satellite: 1663
# SGP4 Error 1 for Satellite: 26315
# SGP4 Error 1 for Satellite: 26955
# SGP4 Error 1 for Satellite: 27171
# SGP4 Error 1 for Satellite: 27077
# SGP4 Error 1 for Satellite: 23661
# SGP4 Error 1 for Satellite: 24195
# SGP4 Error 1 for Satellite: 27428
# SGP4 Error 1 for Satellite: 27427
# SGP4 Error 1 for Satellite: 24025
# SGP4 Error 1 for Satellite: 5281
# SGP4 Error 1 for Satellite: 2129
# SGP4 Error 1 for Satellite: 17198
# SGP4 Error 1 for Satellite: 27180
# SGP4 Error 1 for Satellite: 27223
# SGP4 Error 1 for Satellite: 4475
# SGP4 Error 1 for Satellite: 27064
# SGP4 Error 1 for Satellite: 27254
# SGP4 Error 1 for Satellite: 27251
# SGP4 Error 1 for Satellite: 24780
# SGP4 Error 1 for Satellite: 26428
# SGP4 Error 1 for Satellite: 27342
# SGP4 Error 1 for Satellite: 27101
# SGP4 Error 1 for Satellite: 27295
# SGP4 Error 1 for Satellite: 27289
# SGP4 Error 1 for Satellite: 27164
# SGP4 Error 1 for Satellite: 27225
# SGP4 Error 1 for Satellite: 27187
# SGP4 Error 1 for Satellite: 21990
# SGP4 Error 1 for Satellite: 26940
# SGP4 Error 1 for Satellite: 20586
# SGP4 Error 1 for Satellite: 26641
# SGP4 Error 1 for Satellite: 24493
# Month: 2002-05 -> TLE DF size: 37
# SGP4 Error 1 for Satellite: 27423
# SGP4 Error 1 for Satellite: 26247
# SGP4 Error 1 for Satellite: 27073
# SGP4 Error 1 for Satellite: 7852
# SGP4 Error 1 for Satellite: 26896
# SGP4 Error 1 for Satellite: 26668
# SGP4 Error 1 for Satellite: 27285
# SGP4 Error 1 for Satellite: 27208
# SGP4 Error 1 for Satellite: 27080
# SGP4 Error 1 for Satellite: 26751
# SGP4 Error 1 for Satellite: 27177
# SGP4 Error 1 for Satellite: 27443
# SGP4 Error 1 for Satellite: 27442
# SGP4 Error 1 for Satellite: 8963
# SGP4 Error 1 for Satellite: 19354
# SGP4 Error 1 for Satellite: 24347
# SGP4 Error 1 for Satellite: 13683
# SGP4 Error 1 for Satellite: 22010
# SGP4 Error 1 for Satellite: 27237
# SGP4 Error 1 for Satellite: 27310
# SGP4 Error 1 for Satellite: 27440
# SGP4 Error 1 for Satellite: 27360
# SGP4 Error 1 for Satellite: 27323
# SGP4 Error 1 for Satellite: 27395
# SGP4 Error 1 for Satellite: 10994
# SGP4 Error 1 for Satellite: 5984
# SGP4 Error 1 for Satellite: 27382
# SGP4 Error 1 for Satellite: 27194
# SGP4 Error 1 for Satellite: 27456
# SGP4 Error 1 for Satellite: 27455
# SGP4 Error 1 for Satellite: 24988
# SGP4 Error 1 for Satellite: 27245
# SGP4 Error 1 for Satellite: 26642
# SGP4 Error 1 for Satellite: 26885
# Month: 2002-06 -> TLE DF size: 34
# SGP4 Error 1 for Satellite: 27381
# SGP4 Error 1 for Satellite: 27425
# SGP4 Error 1 for Satellite: 27179
# SGP4 Error 1 for Satellite: 27458
# SGP4 Error 1 for Satellite: 24521
# SGP4 Error 1 for Satellite: 26904
# SGP4 Error 1 for Satellite: 27110
# SGP4 Error 1 for Satellite: 26192
# SGP4 Error 1 for Satellite: 2374
# SGP4 Error 1 for Satellite: 3783
# SGP4 Error 1 for Satellite: 27173
# SGP4 Error 1 for Satellite: 26040
# SGP4 Error 1 for Satellite: 26814
# SGP4 Error 1 for Satellite: 27472
# SGP4 Error 1 for Satellite: 27471
# SGP4 Error 1 for Satellite: 24500
# SGP4 Error 1 for Satellite: 21751
# Month: 2002-07 -> TLE DF size: 17
# SGP4 Error 1 for Satellite: 27071
# SGP4 Error 1 for Satellite: 25726
# SGP4 Error 1 for Satellite: 24599
# SGP4 Error 1 for Satellite: 16220
# SGP4 Error 1 for Satellite: 26179
# SGP4 Error 1 for Satellite: 26180
# SGP4 Error 1 for Satellite: 27193
# SGP4 Error 1 for Satellite: 19764
# SGP4 Error 1 for Satellite: 27287
# SGP4 Error 1 for Satellite: 229
# SGP4 Error 1 for Satellite: 3708
# SGP4 Error 1 for Satellite: 26928
# SGP4 Error 1 for Satellite: 27354
# SGP4 Error 1 for Satellite: 27247
# SGP4 Error 1 for Satellite: 27210
# SGP4 Error 1 for Satellite: 27066
# SGP4 Error 1 for Satellite: 27172
# SGP4 Error 1 for Satellite: 21122
# SGP4 Error 1 for Satellite: 12763
# SGP4 Error 1 for Satellite: 24696
# SGP4 Error 1 for Satellite: 4119
# SGP4 Error 1 for Satellite: 27092
# SGP4 Error 1 for Satellite: 27268
# SGP4 Error 1 for Satellite: 2085
# SGP4 Error 1 for Satellite: 27219
# SGP4 Error 1 for Satellite: 22364
# SGP4 Error 1 for Satellite: 27106
# SGP4 Error 1 for Satellite: 27435
# SGP4 Error 1 for Satellite: 19318
# Month: 2002-08 -> TLE DF size: 31
# SGP4 Error 1 for Satellite: 4622
# SGP4 Error 1 for Satellite: 27505
# SGP4 Error 1 for Satellite: 27506
# SGP4 Error 1 for Satellite: 24477
# SGP4 Error 1 for Satellite: 27507
# SGP4 Error 1 for Satellite: 27081
# SGP4 Error 1 for Satellite: 26811
# SGP4 Error 1 for Satellite: 27241
# SGP4 Error 1 for Satellite: 22448
# SGP4 Error 1 for Satellite: 27521
# SGP4 Error 1 for Satellite: 27522
# SGP4 Error 1 for Satellite: 27524
# SGP4 Error 1 for Satellite: 27523
# SGP4 Error 1 for Satellite: 17715
# SGP4 Error 1 for Satellite: 26217
# SGP4 Error 1 for Satellite: 27377
# SGP4 Error 1 for Satellite: 27236
# SGP4 Error 1 for Satellite: 27162
# SGP4 Error 1 for Satellite: 3391
# SGP4 Error 1 for Satellite: 18086
# SGP4 Error 1 for Satellite: 26269
# SGP4 Error 1 for Satellite: 27248
# SGP4 Error 1 for Satellite: 25887
# SGP4 Error 1 for Satellite: 15909
# SGP4 Error 1 for Satellite: 3587
# SGP4 Error 1 for Satellite: 11285
# SGP4 Error 1 for Satellite: 24760
# SGP4 Error 1 for Satellite: 24103
# SGP4 Error 1 for Satellite: 1808
# SGP4 Error 1 for Satellite: 24646
# SGP4 Error 1 for Satellite: 27379
# SGP4 Error 1 for Satellite: 27205
# SGP4 Error 1 for Satellite: 27337
# SGP4 Error 1 for Satellite: 27532
# SGP4 Error 1 for Satellite: 27143
# SGP4 Error 1 for Satellite: 27269
# Month: 2002-09 -> TLE DF size: 40
# SGP4 Error 1 for Satellite: 27527
# SGP4 Error 1 for Satellite: 5810
# SGP4 Error 1 for Satellite: 22378
# SGP4 Error 1 for Satellite: 27094
# SGP4 Error 1 for Satellite: 20200
# SGP4 Error 1 for Satellite: 4619
# SGP4 Error 1 for Satellite: 24977
# SGP4 Error 1 for Satellite: 27095
# SGP4 Error 1 for Satellite: 27454
# SGP4 Error 1 for Satellite: 211
# SGP4 Error 1 for Satellite: 25574
# SGP4 Error 1 for Satellite: 27275
# SGP4 Error 1 for Satellite: 27537
# SGP4 Error 1 for Satellite: 4850
# SGP4 Error 1 for Satellite: 10269
# SGP4 Error 1 for Satellite: 21376
# SGP4 Error 1 for Satellite: 9727
# SGP4 Error 1 for Satellite: 9711
# SGP4 Error 1 for Satellite: 20446
# SGP4 Error 1 for Satellite: 27074
# SGP4 Error 1 for Satellite: 24375
# SGP4 Error 1 for Satellite: 26291
# SGP4 Error 1 for Satellite: 27539
# SGP4 Error 1 for Satellite: 27490
# SGP4 Error 1 for Satellite: 26224
# SGP4 Error 1 for Satellite: 27543
# SGP4 Error 1 for Satellite: 27548
# SGP4 Error 1 for Satellite: 27549
# SGP4 Error 1 for Satellite: 27547
# Month: 2002-10 -> TLE DF size: 31
# SGP4 Error 1 for Satellite: 27553
# SGP4 Error 1 for Satellite: 26165
# SGP4 Error 1 for Satellite: 26482
# SGP4 Error 1 for Satellite: 27519
# SGP4 Error 1 for Satellite: 11682
# SGP4 Error 1 for Satellite: 27263
# SGP4 Error 1 for Satellite: 24166
# SGP4 Error 1 for Satellite: 27416
# SGP4 Error 1 for Satellite: 27102
# SGP4 Error 1 for Satellite: 26659
# SGP4 Error 1 for Satellite: 24631
# SGP4 Error 1 for Satellite: 26414
# SGP4 Error 1 for Satellite: 27408
# SGP4 Error 1 for Satellite: 27520
# SGP4 Error 1 for Satellite: 26693
# SGP4 Error 1 for Satellite: 26772
# SGP4 Error 1 for Satellite: 27224
# SGP4 Error 1 for Satellite: 27309
# SGP4 Error 1 for Satellite: 23307
# SGP4 Error 1 for Satellite: 27452
# SGP4 Error 1 for Satellite: 22922
# SGP4 Error 1 for Satellite: 806
# SGP4 Error 1 for Satellite: 11156
# SGP4 Error 1 for Satellite: 12760
# SGP4 Error 1 for Satellite: 26317
# SGP4 Error 1 for Satellite: 27100
# SGP4 Error 1 for Satellite: 26699
# SGP4 Error 1 for Satellite: 27163
# SGP4 Error 1 for Satellite: 27563
# SGP4 Error 1 for Satellite: 27558
# SGP4 Error 1 for Satellite: 841
# SGP4 Error 1 for Satellite: 27316
# SGP4 Error 1 for Satellite: 2611
# SGP4 Error 1 for Satellite: 27108
# Month: 2002-11 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 19963
# SGP4 Error 1 for Satellite: 26324
# SGP4 Error 1 for Satellite: 27589
# SGP4 Error 1 for Satellite: 27496
# SGP4 Error 1 for Satellite: 27514
# SGP4 Error 1 for Satellite: 27565
# SGP4 Error 1 for Satellite: 16085
# SGP4 Error 1 for Satellite: 27556
# SGP4 Error 1 for Satellite: 17131
# SGP4 Error 1 for Satellite: 22658
# SGP4 Error 1 for Satellite: 27541
# SGP4 Error 1 for Satellite: 27564
# SGP4 Error 1 for Satellite: 27557
# SGP4 Error 1 for Satellite: 27517
# SGP4 Error 1 for Satellite: 27235
# SGP4 Error 1 for Satellite: 25694
# SGP4 Error 1 for Satellite: 26215
# SGP4 Error 1 for Satellite: 27103
# SGP4 Error 1 for Satellite: 26656
# SGP4 Error 1 for Satellite: 18677
# SGP4 Error 1 for Satellite: 24070
# SGP4 Error 1 for Satellite: 27495
# SGP4 Error 1 for Satellite: 15188
# SGP4 Error 1 for Satellite: 27086
# SGP4 Error 1 for Satellite: 27448
# SGP4 Error 1 for Satellite: 13805
# SGP4 Error 1 for Satellite: 26708
# SGP4 Error 1 for Satellite: 13091
# SGP4 Error 1 for Satellite: 27637
# SGP4 Error 1 for Satellite: 15182
# Month: 2002-12 -> TLE DF size: 33
# SGP4 Error 1 for Satellite: 27630
# SGP4 Error 1 for Satellite: 27623
# SGP4 Error 1 for Satellite: 21378
# SGP4 Error 1 for Satellite: 27631
# SGP4 Error 1 for Satellite: 27082
# SGP4 Error 1 for Satellite: 17622
# SGP4 Error 1 for Satellite: 25194
# SGP4 Error 1 for Satellite: 16223
# SGP4 Error 1 for Satellite: 27117
# SGP4 Error 1 for Satellite: 27615
# SGP4 Error 1 for Satellite: 23878
# SGP4 Error 1 for Satellite: 26746
# SGP4 Error 1 for Satellite: 26322
# SGP4 Error 1 for Satellite: 27713
# SGP4 Error 1 for Satellite: 27592
# SGP4 Error 1 for Satellite: 19190
# SGP4 Error 1 for Satellite: 26929
# SGP4 Error 1 for Satellite: 27067
# SGP4 Error 1 for Satellite: 23174
# SGP4 Error 1 for Satellite: 18332
# SGP4 Error 1 for Satellite: 4866
# SGP4 Error 1 for Satellite: 27070
# SGP4 Error 1 for Satellite: 27562
# SGP4 Error 1 for Satellite: 17311
# Month: 2003-01 -> TLE DF size: 27
# SGP4 Error 1 for Satellite: 27647
# SGP4 Error 1 for Satellite: 12824
# SGP4 Error 1 for Satellite: 27614
# SGP4 Error 1 for Satellite: 18083
# SGP4 Error 1 for Satellite: 27682
# SGP4 Error 1 for Satellite: 24095
# SGP4 Error 1 for Satellite: 26349
# SGP4 Error 1 for Satellite: 17981
# SGP4 Error 1 for Satellite: 27090
# SGP4 Error 1 for Satellite: 1687
# SGP4 Error 1 for Satellite: 26305
# SGP4 Error 1 for Satellite: 7941
# SGP4 Error 1 for Satellite: 27249
# SGP4 Error 1 for Satellite: 24156
# SGP4 Error 1 for Satellite: 19817
# SGP4 Error 1 for Satellite: 26182
# Month: 2003-02 -> TLE DF size: 17
# SGP4 Error 1 for Satellite: 24847
# SGP4 Error 1 for Satellite: 26289
# SGP4 Error 1 for Satellite: 26345
# SGP4 Error 1 for Satellite: 2788
# SGP4 Error 1 for Satellite: 25236
# SGP4 Error 1 for Satellite: 24838
# SGP4 Error 1 for Satellite: 26296
# SGP4 Error 1 for Satellite: 11419
# SGP4 Error 1 for Satellite: 27485
# SGP4 Error 1 for Satellite: 27645
# SGP4 Error 1 for Satellite: 10241
# SGP4 Error 1 for Satellite: 27260
# SGP4 Error 1 for Satellite: 26651
# SGP4 Error 1 for Satellite: 26753
# SGP4 Error 1 for Satellite: 5148
# Month: 2003-03 -> TLE DF size: 16
# SGP4 Error 1 for Satellite: 24124
# SGP4 Error 1 for Satellite: 7943
# SGP4 Error 1 for Satellite: 27529
# SGP4 Error 1 for Satellite: 18644
# SGP4 Error 1 for Satellite: 27078
# SGP4 Error 1 for Satellite: 27488
# SGP4 Error 1 for Satellite: 27708
# SGP4 Error 1 for Satellite: 27777
# SGP4 Error 1 for Satellite: 27776
# SGP4 Error 1 for Satellite: 472
# SGP4 Error 1 for Satellite: 27484
# SGP4 Error 1 for Satellite: 25240
# SGP4 Error 1 for Satellite: 27076
# SGP4 Error 1 for Satellite: 27782
# SGP4 Error 1 for Satellite: 23857
# SGP4 Error 1 for Satellite: 19332
# SGP4 Error 1 for Satellite: 26344
# Month: 2003-04 -> TLE DF size: 18
# SGP4 Error 1 for Satellite: 26304
# SGP4 Error 1 for Satellite: 27246
# SGP4 Error 1 for Satellite: 27552
# SGP4 Error 1 for Satellite: 27774
# SGP4 Error 1 for Satellite: 27756
# SGP4 Error 1 for Satellite: 14360
# SGP4 Error 1 for Satellite: 27709
# SGP4 Error 1 for Satellite: 27065
# SGP4 Error 1 for Satellite: 25855
# SGP4 Error 1 for Satellite: 23178
# SGP4 Error 1 for Satellite: 26169
# SGP4 Error 1 for Satellite: 27113
# SGP4 Error 1 for Satellite: 5137
# SGP4 Error 1 for Satellite: 21150
# SGP4 Error 1 for Satellite: 27694
# SGP4 Error 1 for Satellite: 27588
# Month: 2003-05 -> TLE DF size: 20
# SGP4 Error 1 for Satellite: 20390
# SGP4 Error 1 for Satellite: 25895
# SGP4 Error 1 for Satellite: 27824
# SGP4 Error 1 for Satellite: 24310
# SGP4 Error 1 for Satellite: 17332
# SGP4 Error 1 for Satellite: 5638
# SGP4 Error 1 for Satellite: 27181
# SGP4 Error 1 for Satellite: 20444
# SGP4 Error 1 for Satellite: 17670
# SGP4 Error 1 for Satellite: 22413
# SGP4 Error 1 for Satellite: 22401
# SGP4 Error 1 for Satellite: 27705
# SGP4 Error 1 for Satellite: 5282
# Month: 2003-06 -> TLE DF size: 16
# SGP4 Error 1 for Satellite: 24283
# SGP4 Error 1 for Satellite: 27486
# SGP4 Error 1 for Satellite: 27836
# SGP4 Error 1 for Satellite: 27627
# SGP4 Error 1 for Satellite: 27242
# SGP4 Error 1 for Satellite: 26409
# SGP4 Error 1 for Satellite: 27835
# Month: 2003-07 -> TLE DF size: 10
# SGP4 Error 1 for Satellite: 4330
# SGP4 Error 1 for Satellite: 27587
# SGP4 Error 1 for Satellite: 11286
# SGP4 Error 1 for Satellite: 27917
# SGP4 Error 1 for Satellite: 24655
# SGP4 Error 1 for Satellite: 22875
# SGP4 Error 1 for Satellite: 20871
# SGP4 Error 1 for Satellite: 27925
# SGP4 Error 6 for Satellite: 27924
# SGP4 Error 1 for Satellite: 27935
# SGP4 Error 1 for Satellite: 27857
# SGP4 Error 1 for Satellite: 840
# SGP4 Error 1 for Satellite: 27447
# SGP4 Error 1 for Satellite: 26219
# SGP4 Error 1 for Satellite: 27099
# SGP4 Error 1 for Satellite: 27681
# SGP4 Error 1 for Satellite: 27874
# Month: 2003-08 -> TLE DF size: 20
# ...
# SGP4 Error 1 for Satellite: 36252
# SGP4 Error 1 for Satellite: 40122
# SGP4 Error 1 for Satellite: 37328
# SGP4 Error 1 for Satellite: 38805
# SGP4 Error 1 for Satellite: 29034
# SGP4 Error 1 for Satellite: 34645
# SGP4 Error 1 for Satellite: 34423
# SGP4 Error 1 for Satellite: 25833
# SGP4 Error 1 for Satellite: 35913
# SGP4 Error 1 for Satellite: 31170
# SGP4 Error 1 for Satellite: 28963
# SGP4 Error 1 for Satellite: 39388
# SGP4 Error 1 for Satellite: 40325
# SGP4 Error 1 for Satellite: 28064
# SGP4 Error 1 for Satellite: 39387
# SGP4 Error 1 for Satellite: 25668
# SGP4 Error 1 for Satellite: 36930
# SGP4 Error 1 for Satellite: 31869
# SGP4 Error 1 for Satellite: 39292
# SGP4 Error 1 for Satellite: 35388
# SGP4 Error 1 for Satellite: 40257
# SGP4 Error 1 for Satellite: 40543
# SGP4 Error 1 for Satellite: 37122
# SGP4 Error 1 for Satellite: 17037
# SGP4 Error 1 for Satellite: 27590
# Month: 2015-03 -> TLE DF size: 58
# SGP4 Error 1 for Satellite: 36919
# SGP4 Error 1 for Satellite: 21622
# SGP4 Error 1 for Satellite: 34676
# SGP4 Error 1 for Satellite: 39396
# SGP4 Error 1 for Satellite: 40419
# SGP4 Error 1 for Satellite: 40455
# SGP4 Error 1 for Satellite: 32083
# SGP4 Error 1 for Satellite: 21944
# SGP4 Error 1 for Satellite: 35733
# SGP4 Error 1 for Satellite: 21825
# SGP4 Error 1 for Satellite: 40488
# SGP4 Error 1 for Satellite: 38972
# SGP4 Error 1 for Satellite: 37310
# SGP4 Error 1 for Satellite: 36556
# SGP4 Error 1 for Satellite: 35916
# SGP4 Error 1 for Satellite: 31803
# SGP4 Error 1 for Satellite: 30189
# SGP4 Error 1 for Satellite: 37015
# SGP4 Error 1 for Satellite: 35228
# SGP4 Error 1 for Satellite: 36544
# SGP4 Error 1 for Satellite: 40595
# SGP4 Error 1 for Satellite: 35803
# SGP4 Error 1 for Satellite: 32495
# SGP4 Error 1 for Satellite: 40590
# SGP4 Error 1 for Satellite: 40591
# SGP4 Error 1 for Satellite: 34795
# SGP4 Error 1 for Satellite: 12072
# SGP4 Error 1 for Satellite: 36972
# SGP4 Error 1 for Satellite: 24094
# SGP4 Error 1 for Satellite: 30748
# SGP4 Error 1 for Satellite: 32452
# SGP4 Error 1 for Satellite: 33856
# SGP4 Error 1 for Satellite: 33644
# SGP4 Error 1 for Satellite: 34364
# SGP4 Error 1 for Satellite: 34436
# SGP4 Error 1 for Satellite: 40589
# SGP4 Error 1 for Satellite: 36905
# SGP4 Error 1 for Satellite: 40597
# SGP4 Error 1 for Satellite: 24243
# SGP4 Error 6 for Satellite: 40292
# SGP4 Error 1 for Satellite: 31939
# SGP4 Error 1 for Satellite: 40622
# SGP4 Error 1 for Satellite: 40621
# SGP4 Error 1 for Satellite: 40627
# SGP4 Error 1 for Satellite: 40628
# SGP4 Error 1 for Satellite: 40625
# SGP4 Error 1 for Satellite: 40623
# SGP4 Error 1 for Satellite: 40634
# SGP4 Error 1 for Satellite: 40629
# SGP4 Error 1 for Satellite: 40620
# SGP4 Error 1 for Satellite: 40626
# SGP4 Error 1 for Satellite: 40639
# SGP4 Error 1 for Satellite: 40632
# SGP4 Error 1 for Satellite: 40638
# SGP4 Error 1 for Satellite: 40636
# SGP4 Error 1 for Satellite: 34945
# SGP4 Error 1 for Satellite: 36904
# Month: 2015-04 -> TLE DF size: 71
# SGP4 Error 1 for Satellite: 35710
# SGP4 Error 1 for Satellite: 40640
# SGP4 Error 1 for Satellite: 40633
# SGP4 Error 1 for Satellite: 30055
# SGP4 Error 6 for Satellite: 40190
# SGP4 Error 1 for Satellite: 31549
# SGP4 Error 1 for Satellite: 40635
# SGP4 Error 1 for Satellite: 38026
# SGP4 Error 1 for Satellite: 30712
# SGP4 Error 1 for Satellite: 40637
# SGP4 Error 1 for Satellite: 40619
# SGP4 Error 1 for Satellite: 37016
# SGP4 Error 1 for Satellite: 37511
# SGP4 Error 1 for Satellite: 30692
# SGP4 Error 1 for Satellite: 38317
# SGP4 Error 1 for Satellite: 39795
# SGP4 Error 1 for Satellite: 40389
# SGP4 Error 1 for Satellite: 33974
# SGP4 Error 1 for Satellite: 40253
# SGP4 Error 1 for Satellite: 32078
# SGP4 Error 1 for Satellite: 26986
# SGP4 Error 1 for Satellite: 30421
# SGP4 Error 1 for Satellite: 34982
# SGP4 Error 6 for Satellite: 31875
# SGP4 Error 1 for Satellite: 40458
# SGP4 Error 1 for Satellite: 22254
# SGP4 Error 1 for Satellite: 4648
# SGP4 Error 1 for Satellite: 29838
# SGP4 Error 1 for Satellite: 36674
# SGP4 Error 1 for Satellite: 37718
# SGP4 Error 1 for Satellite: 34491
# SGP4 Error 1 for Satellite: 37066
# SGP4 Error 1 for Satellite: 36051
# SGP4 Error 1 for Satellite: 37431
# SGP4 Error 1 for Satellite: 40596
# SGP4 Error 1 for Satellite: 34809
# SGP4 Error 1 for Satellite: 37472
# Month: 2015-05 -> TLE DF size: 47
# SGP4 Error 1 for Satellite: 31790
# SGP4 Error 1 for Satellite: 33910
# SGP4 Error 1 for Satellite: 35386
# SGP4 Error 1 for Satellite: 4673
# SGP4 Error 1 for Satellite: 37970
# SGP4 Error 1 for Satellite: 40668
# SGP4 Error 1 for Satellite: 40394
# SGP4 Error 1 for Satellite: 40312
# SGP4 Error 6 for Satellite: 35034
# SGP4 Error 1 for Satellite: 38918
# SGP4 Error 1 for Satellite: 40138
# SGP4 Error 1 for Satellite: 12184
# SGP4 Error 1 for Satellite: 32237
# SGP4 Error 1 for Satellite: 40503
# SGP4 Error 1 for Satellite: 35914
# SGP4 Error 1 for Satellite: 25063
# SGP4 Error 1 for Satellite: 27063
# SGP4 Error 6 for Satellite: 40392
# SGP4 Error 1 for Satellite: 40584
# SGP4 Error 1 for Satellite: 40279
# SGP4 Error 1 for Satellite: 30195
# SGP4 Error 1 for Satellite: 23104
# SGP4 Error 1 for Satellite: 35652
# SGP4 Error 1 for Satellite: 39293
# SGP4 Error 1 for Satellite: 35021
# SGP4 Error 1 for Satellite: 30963
# SGP4 Error 1 for Satellite: 40430
# SGP4 Error 1 for Satellite: 22020
# SGP4 Error 1 for Satellite: 34373
# SGP4 Error 1 for Satellite: 6939
# SGP4 Error 1 for Satellite: 39290
# SGP4 Error 1 for Satellite: 38167
# SGP4 Error 1 for Satellite: 39551
# Month: 2015-06 -> TLE DF size: 39
# SGP4 Error 1 for Satellite: 22411
# SGP4 Error 1 for Satellite: 38902
# SGP4 Error 1 for Satellite: 38898
# SGP4 Error 6 for Satellite: 40801
# SGP4 Error 1 for Satellite: 40557
# SGP4 Error 1 for Satellite: 38914
# SGP4 Error 1 for Satellite: 40714
# SGP4 Error 1 for Satellite: 40446
# SGP4 Error 1 for Satellite: 38211
# SGP4 Error 1 for Satellite: 35889
# SGP4 Error 1 for Satellite: 12389
# SGP4 Error 1 for Satellite: 39449
# SGP4 Error 1 for Satellite: 37302
# SGP4 Error 1 for Satellite: 36027
# SGP4 Error 1 for Satellite: 39398
# SGP4 Error 1 for Satellite: 14484
# SGP4 Error 1 for Satellite: 40745
# SGP4 Error 1 for Satellite: 36912
# Month: 2015-07 -> TLE DF size: 27
# SGP4 Error 1 for Satellite: 40359
# SGP4 Error 1 for Satellite: 40457
# SGP4 Error 1 for Satellite: 34356
# SGP4 Error 1 for Satellite: 38894
# SGP4 Error 1 for Satellite: 26238
# SGP4 Error 1 for Satellite: 20347
# SGP4 Error 1 for Satellite: 40423
# SGP4 Error 1 for Satellite: 35920
# SGP4 Error 1 for Satellite: 37955
# SGP4 Error 1 for Satellite: 11007
# SGP4 Error 1 for Satellite: 2161
# SGP4 Error 1 for Satellite: 34100
# SGP4 Error 1 for Satellite: 36669
# SGP4 Error 1 for Satellite: 40700
# SGP4 Error 1 for Satellite: 35741
# SGP4 Error 1 for Satellite: 40453
# SGP4 Error 1 for Satellite: 20859
# SGP4 Error 1 for Satellite: 40429
# SGP4 Error 1 for Satellite: 31712
# SGP4 Error 1 for Satellite: 30910
# SGP4 Error 1 for Satellite: 31694
# SGP4 Error 1 for Satellite: 12903
# Month: 2015-08 -> TLE DF size: 31
# SGP4 Error 1 for Satellite: 39262
# SGP4 Error 1 for Satellite: 34073
# SGP4 Error 1 for Satellite: 31586
# SGP4 Error 1 for Satellite: 34794
# SGP4 Error 1 for Satellite: 40886
# SGP4 Error 1 for Satellite: 40459
# SGP4 Error 1 for Satellite: 40702
# SGP4 Error 6 for Satellite: 40542
# SGP4 Error 1 for Satellite: 39385
# SGP4 Error 1 for Satellite: 28678
# SGP4 Error 1 for Satellite: 40667
# SGP4 Error 1 for Satellite: 37812
# SGP4 Error 1 for Satellite: 30292
# SGP4 Error 1 for Satellite: 33790
# SGP4 Error 1 for Satellite: 26311
# SGP4 Error 1 for Satellite: 34662
# SGP4 Error 1 for Satellite: 40460
# SGP4 Error 1 for Satellite: 12909
# Month: 2015-09 -> TLE DF size: 29
# SGP4 Error 1 for Satellite: 40929
# SGP4 Error 1 for Satellite: 40428
# SGP4 Error 1 for Satellite: 40432
# SGP4 Error 1 for Satellite: 40945
# SGP4 Error 1 for Satellite: 36890
# SGP4 Error 1 for Satellite: 23534
# SGP4 Error 1 for Satellite: 39229
# SGP4 Error 1 for Satellite: 40427
# SGP4 Error 1 for Satellite: 40451
# SGP4 Error 1 for Satellite: 40422
# SGP4 Error 1 for Satellite: 40454
# SGP4 Error 1 for Satellite: 28324
# SGP4 Error 1 for Satellite: 7930
# SGP4 Error 1 for Satellite: 38895
# SGP4 Error 1 for Satellite: 22498
# SGP4 Error 1 for Satellite: 35957
# SGP4 Error 1 for Satellite: 39389
# SGP4 Error 1 for Satellite: 33883
# SGP4 Error 1 for Satellite: 24938
# SGP4 Error 1 for Satellite: 40324
# SGP4 Error 1 for Satellite: 37209
# SGP4 Error 1 for Satellite: 25843
# Month: 2015-10 -> TLE DF size: 36
# SGP4 Error 1 for Satellite: 40445
# SGP4 Error 1 for Satellite: 30909
# SGP4 Error 1 for Satellite: 34921
# SGP4 Error 1 for Satellite: 31140
# SGP4 Error 6 for Satellite: 37459
# SGP4 Error 1 for Satellite: 34727
# SGP4 Error 1 for Satellite: 40456
# SGP4 Error 1 for Satellite: 34360
# SGP4 Error 1 for Satellite: 25064
# SGP4 Error 1 for Satellite: 24115
# SGP4 Error 1 for Satellite: 4941
# SGP4 Error 1 for Satellite: 40241
# SGP4 Error 1 for Satellite: 39407
# SGP4 Error 1 for Satellite: 36480
# SGP4 Error 1 for Satellite: 32765
# SGP4 Error 1 for Satellite: 39393
# SGP4 Error 1 for Satellite: 29099
# SGP4 Error 1 for Satellite: 39401
# Month: 2015-11 -> TLE DF size: 28
# SGP4 Error 1 for Satellite: 38268
# SGP4 Error 1 for Satellite: 37151
# SGP4 Error 1 for Satellite: 39399
# SGP4 Error 1 for Satellite: 31276
# SGP4 Error 1 for Satellite: 40587
# SGP4 Error 1 for Satellite: 41102
# SGP4 Error 1 for Satellite: 41098
# SGP4 Error 1 for Satellite: 39408
# SGP4 Error 1 for Satellite: 39394
# SGP4 Error 1 for Satellite: 39391
# SGP4 Error 6 for Satellite: 40744
# SGP4 Error 6 for Satellite: 35399
# SGP4 Error 1 for Satellite: 29759
# SGP4 Error 1 for Satellite: 39406
# SGP4 Error 1 for Satellite: 30226
# SGP4 Error 1 for Satellite: 39390
# SGP4 Error 1 for Satellite: 39402
# SGP4 Error 1 for Satellite: 41043
# SGP4 Error 1 for Satellite: 34812
# SGP4 Error 1 for Satellite: 39861
# SGP4 Error 1 for Satellite: 35463
# SGP4 Error 1 for Satellite: 41125
# SGP4 Error 1 for Satellite: 41114
# SGP4 Error 1 for Satellite: 40713
# SGP4 Error 1 for Satellite: 39593
# SGP4 Error 1 for Satellite: 36474
# SGP4 Error 1 for Satellite: 33606
# SGP4 Error 1 for Satellite: 41178
# SGP4 Error 1 for Satellite: 40742
# SGP4 Error 1 for Satellite: 26277
# SGP4 Error 1 for Satellite: 41112
# SGP4 Error 1 for Satellite: 41109
# SGP4 Error 1 for Satellite: 39409
# SGP4 Error 1 for Satellite: 36740
# SGP4 Error 1 for Satellite: 34515
# SGP4 Error 1 for Satellite: 41027
# SGP4 Error 1 for Satellite: 10246
# SGP4 Error 1 for Satellite: 40452
# SGP4 Error 1 for Satellite: 41110
# SGP4 Error 1 for Satellite: 41111
# Month: 2015-12 -> TLE DF size: 51
# SGP4 Error 1 for Satellite: 41107
# SGP4 Error 1 for Satellite: 39386
# SGP4 Error 1 for Satellite: 16866
# SGP4 Error 1 for Satellite: 40743
# SGP4 Error 1 for Satellite: 40309
# SGP4 Error 1 for Satellite: 34820
# SGP4 Error 1 for Satellite: 41190
# SGP4 Error 1 for Satellite: 22553
# SGP4 Error 1 for Satellite: 41115
# SGP4 Error 1 for Satellite: 34943
# SGP4 Error 1 for Satellite: 40983
# SGP4 Error 1 for Satellite: 34188
# SGP4 Error 1 for Satellite: 40812
# SGP4 Error 1 for Satellite: 34157
# SGP4 Error 1 for Satellite: 35553
# SGP4 Error 1 for Satellite: 40893
# Month: 2016-01 -> TLE DF size: 21
# SGP4 Error 1 for Satellite: 40791
# SGP4 Error 1 for Satellite: 39395
# SGP4 Error 1 for Satellite: 37874
# SGP4 Error 1 for Satellite: 40736
# SGP4 Error 1 for Satellite: 24092
# SGP4 Error 1 for Satellite: 35750
# SGP4 Error 1 for Satellite: 36920
# SGP4 Error 1 for Satellite: 30970
# SGP4 Error 1 for Satellite: 28226
# Month: 2016-02 -> TLE DF size: 21
# SGP4 Error 6 for Satellite: 40885
# SGP4 Error 1 for Satellite: 40421
# SGP4 Error 1 for Satellite: 37797
# SGP4 Error 6 for Satellite: 31582
# SGP4 Error 1 for Satellite: 40722
# SGP4 Error 1 for Satellite: 34573
# SGP4 Error 1 for Satellite: 36835
# SGP4 Error 1 for Satellite: 41326
# SGP4 Error 1 for Satellite: 22506
# SGP4 Error 1 for Satellite: 26481
# SGP4 Error 1 for Satellite: 38905
# SGP4 Error 1 for Satellite: 22788
# SGP4 Error 1 for Satellite: 40948
# SGP4 Error 1 for Satellite: 31621
# SGP4 Error 1 for Satellite: 41100
# SGP4 Error 1 for Satellite: 34374
# SGP4 Error 1 for Satellite: 39405
# SGP4 Error 1 for Satellite: 35821
# SGP4 Error 1 for Satellite: 41392
# SGP4 Error 1 for Satellite: 40550
# SGP4 Error 6 for Satellite: 39226
# SGP4 Error 1 for Satellite: 41327
# SGP4 Error 1 for Satellite: 40512
# SGP4 Error 1 for Satellite: 40897
# SGP4 Error 1 for Satellite: 38941
# SGP4 Error 1 for Satellite: 36897
# Month: 2016-03 -> TLE DF size: 34
# SGP4 Error 1 for Satellite: 41437
# SGP4 Error 1 for Satellite: 31908
# SGP4 Error 1 for Satellite: 41451
# SGP4 Error 1 for Satellite: 41450
# SGP4 Error 1 for Satellite: 34855
# SGP4 Error 1 for Satellite: 40939
# SGP4 Error 1 for Satellite: 22845
# SGP4 Error 1 for Satellite: 40944
# SGP4 Error 1 for Satellite: 41454
# SGP4 Error 1 for Satellite: 41453
# SGP4 Error 1 for Satellite: 28163
# SGP4 Error 1 for Satellite: 41443
# SGP4 Error 1 for Satellite: 41116
# SGP4 Error 1 for Satellite: 41448
# SGP4 Error 1 for Satellite: 41449
# SGP4 Error 1 for Satellite: 41438
# SGP4 Error 1 for Satellite: 38328
# SGP4 Error 1 for Satellite: 34339
# SGP4 Error 1 for Satellite: 41462
# SGP4 Error 1 for Satellite: 41467
# Month: 2016-04 -> TLE DF size: 29
# SGP4 Error 1 for Satellite: 34156
# SGP4 Error 1 for Satellite: 39597
# SGP4 Error 1 for Satellite: 36877
# SGP4 Error 1 for Satellite: 34435
# SGP4 Error 1 for Satellite: 37338
# SGP4 Error 6 for Satellite: 41452
# SGP4 Error 1 for Satellite: 11849
# SGP4 Error 1 for Satellite: 41104
# SGP4 Error 1 for Satellite: 40723
# SGP4 Error 1 for Satellite: 39400
# SGP4 Error 1 for Satellite: 40957
# SGP4 Error 1 for Satellite: 28685
# SGP4 Error 1 for Satellite: 40725
# Month: 2016-05 -> TLE DF size: 20
# SGP4 Error 1 for Satellite: 36907
# SGP4 Error 1 for Satellite: 35623
# SGP4 Error 1 for Satellite: 20971
# SGP4 Error 6 for Satellite: 41124
# SGP4 Error 1 for Satellite: 29021
# SGP4 Error 1 for Satellite: 40728
# SGP4 Error 1 for Satellite: 40727
# SGP4 Error 1 for Satellite: 34225
# SGP4 Error 1 for Satellite: 40724
# SGP4 Error 1 for Satellite: 39000
# SGP4 Error 1 for Satellite: 38890
# Month: 2016-06 -> TLE DF size: 17
# SGP4 Error 1 for Satellite: 41455
# SGP4 Error 1 for Satellite: 41627
# SGP4 Error 1 for Satellite: 41035
# SGP4 Error 1 for Satellite: 41630
# SGP4 Error 1 for Satellite: 41631
# SGP4 Error 1 for Satellite: 41633
# SGP4 Error 1 for Satellite: 41632
# SGP4 Error 1 for Satellite: 34134
# SGP4 Error 1 for Satellite: 41239
# SGP4 Error 1 for Satellite: 37554
# SGP4 Error 1 for Satellite: 26631
# SGP4 Error 1 for Satellite: 29645
# SGP4 Error 1 for Satellite: 41640
# SGP4 Error 1 for Satellite: 40726
# SGP4 Error 1 for Satellite: 34698
# SGP4 Error 1 for Satellite: 40729
# SGP4 Error 1 for Satellite: 41673
# SGP4 Error 1 for Satellite: 41674
# SGP4 Error 1 for Satellite: 41628
# SGP4 Error 1 for Satellite: 40741
# Month: 2016-07 -> TLE DF size: 27
# SGP4 Error 1 for Satellite: 40739
# SGP4 Error 1 for Satellite: 40737
# SGP4 Error 1 for Satellite: 40738
# SGP4 Error 1 for Satellite: 41044
# SGP4 Error 1 for Satellite: 33903
# SGP4 Error 6 for Satellite: 41733
# SGP4 Error 1 for Satellite: 40955
# SGP4 Error 1 for Satellite: 41637
# SGP4 Error 1 for Satellite: 40740
# SGP4 Error 6 for Satellite: 41672
# SGP4 Error 1 for Satellite: 41629
# SGP4 Error 1 for Satellite: 41636
# SGP4 Error 1 for Satellite: 30839
# SGP4 Error 1 for Satellite: 39383
# Month: 2016-08 -> TLE DF size: 21
# SGP4 Error 1 for Satellite: 2253
# SGP4 Error 1 for Satellite: 30819
# SGP4 Error 1 for Satellite: 30962
# SGP4 Error 6 for Satellite: 41391
# SGP4 Error 6 for Satellite: 41754
# SGP4 Error 1 for Satellite: 1857
# SGP4 Error 1 for Satellite: 34296
# SGP4 Error 1 for Satellite: 41626
# SGP4 Error 1 for Satellite: 40980
# SGP4 Error 1 for Satellite: 39789
# SGP4 Error 1 for Satellite: 34075
# SGP4 Error 1 for Satellite: 41781
# SGP4 Error 1 for Satellite: 34931
# SGP4 Error 1 for Satellite: 41780
# SGP4 Error 1 for Satellite: 41778
# SGP4 Error 1 for Satellite: 41779
# SGP4 Error 1 for Satellite: 20874
# SGP4 Error 1 for Satellite: 28953
# SGP4 Error 1 for Satellite: 40956
# SGP4 Error 1 for Satellite: 40950
# SGP4 Error 1 for Satellite: 20905
# SGP4 Error 1 for Satellite: 41387
# SGP4 Error 1 for Satellite: 40954
# SGP4 Error 1 for Satellite: 27706
# SGP4 Error 1 for Satellite: 41730
# SGP4 Error 1 for Satellite: 22017
# SGP4 Error 1 for Satellite: 34421
# SGP4 Error 1 for Satellite: 41767
# SGP4 Error 1 for Satellite: 41766
# SGP4 Error 1 for Satellite: 27125
# SGP4 Error 1 for Satellite: 41625
# SGP4 Error 1 for Satellite: 24963
# Month: 2016-09 -> TLE DF size: 38
